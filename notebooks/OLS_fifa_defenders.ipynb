# %% [markdown]
# # <u>Purspose</u>: Create fifa players datasets
# ## <u>Description</u>:
# ## Create datasets of players by position.

# %%
# %run functions.ipynb

# %%
goal_keepers = ['GK']
defenders = ['RWB', 'RCB', 'RB', 'LCB', 'CB', 'LWB', 'LB']
def_mid_fielders = ['LDM', 'CDM','RDM']
mid_fielders = ['CM', 'RCM', 'RM', 'LCM', 'LM']
attack_mid_fielders = ['LAM', 'CAM', 'RAM']
forwards = ['RF', 'CF','LF', 'LW', 'RW']
strikers = ['ST', 'RS', 'LS']

goal_keepers_l = 'GK'
defenders_l = 'RWB', 'RCB', 'RB', 'LCB', 'CB', 'LWB', 'LB'
def_mid_fielders_l = 'LDM', 'CDM','RDM'
mid_fielders_l = 'CM', 'RCM', 'RM', 'LCM', 'LM'
attack_mid_fielders_l = 'LAM', 'CAM', 'RAM'
forwards_l = 'RF', 'CF','LF', 'LW', 'RW'
strikers_l = 'ST', 'RS', 'LS'

# %% [markdown]
# ## - goalkeepers dataset

# %%
# Connect to DB
conn, cursor= connect()

import pandas
# sql = """ SELECT * from players where field_position in ('GK') """
sql = f"SELECT * from players where field_position in {defenders_l} "

defenders_data = pandas.read_sql(sql, con=conn)


# calulate player ratings
defenders_data['rating'] = (defenders_data['overall'] + defenders_data['potential'])/2
# Disconnect from DB
disconnect(conn, cursor)

defenders_data = create_players_dataframes(defenders_data, columns_to_keep)
# display(goal_keepers_data)
defenders_data_filtered = create_players_dataframes(defenders_data, ['standing_tackle', 'reactions', 'marking', 'rating', 'field_position', 'potential', 'overall'])
# display(goalkeepers_data_filtered)
run_through_OLS_Model(defenders_data_filtered, defenders)
# Out:
# Connected!
#  ********* Current Position: RWB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     95.00
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           1.02e-23
# Time:                        18:20:53   Log-Likelihood:                -163.23
# No. Observations:                  69   AIC:                             334.5
# Df Residuals:                      65   BIC:                             343.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.2643      0.062      4.296      0.000       0.141       0.387
# marking             0.1429      0.086      1.654      0.103      -0.030       0.315
# standing_tackle     0.3032      0.082      3.692      0.000       0.139       0.467
# const              23.7696      2.757      8.623      0.000      18.264      29.275
# ==============================================================================
# Omnibus:                        0.275   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.872   Jarque-Bera (JB):                0.460
# Skew:                           0.026   Prob(JB):                        0.794
# Kurtosis:                       2.603   Cond. No.                         924.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#  ********* Current Position: RCB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'marking', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     933.8
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          5.57e-210
# Time:                        18:20:53   Log-Likelihood:                -1149.8
# No. Observations:                 529   AIC:                             2308.
# Df Residuals:                     525   BIC:                             2325.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.1418      0.019      7.566      0.000       0.105       0.179
# marking             0.2061      0.021      9.689      0.000       0.164       0.248
# standing_tackle     0.4427      0.026     16.906      0.000       0.391       0.494
# const              16.8494      1.047     16.099      0.000      14.793      18.905
# ==============================================================================
# Omnibus:                        4.588   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                4.375
# Skew:                           0.207   Prob(JB):                        0.112
# Kurtosis:                       3.166   Cond. No.                     1.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'reactions', 'marking'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.741
# Method:                 Least Squares   F-statistic:                     984.5
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          1.20e-301
# Time:                        18:20:53   Log-Likelihood:                -2534.3
# No. Observations:                1032   AIC:                             5077.
# Df Residuals:                    1028   BIC:                             5096.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.2056      0.017     11.819      0.000       0.171       0.240
# marking             0.1085      0.018      6.083      0.000       0.073       0.143
# standing_tackle     0.3902      0.022     17.799      0.000       0.347       0.433
# const              22.9462      0.851     26.974      0.000      21.277      24.615
# ==============================================================================
# Omnibus:                        1.034   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.596   Jarque-Bera (JB):                0.952
# Skew:                          -0.071   Prob(JB):                        0.621
# Kurtosis:                       3.041   Cond. No.                     1.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LCB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'marking', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     842.2
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          6.57e-198
# Time:                        18:20:53   Log-Likelihood:                -1150.2
# No. Observations:                 518   AIC:                             2308.
# Df Residuals:                     514   BIC:                             2325.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.1441      0.020      7.090      0.000       0.104       0.184
# marking             0.1938      0.023      8.357      0.000       0.148       0.239
# standing_tackle     0.4539      0.027     16.803      0.000       0.401       0.507
# const              16.7600      1.102     15.215      0.000      14.596      18.924
# ==============================================================================
# Omnibus:                       11.173   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.273
# Skew:                           0.350   Prob(JB):                      0.00356
# Kurtosis:                       3.176   Cond. No.                     1.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'marking', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     1861.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        18:20:53   Log-Likelihood:                -3332.3
# No. Observations:                1422   AIC:                             6673.
# Df Residuals:                    1418   BIC:                             6694.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.1524      0.012     12.338      0.000       0.128       0.177
# marking             0.1576      0.014     11.390      0.000       0.130       0.185
# standing_tackle     0.3963      0.017     23.535      0.000       0.363       0.429
# const              22.7452      0.635     35.814      0.000      21.499      23.991
# ==============================================================================
# Omnibus:                       10.998   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               15.839
# Skew:                           0.005   Prob(JB):                     0.000364
# Kurtosis:                       3.517   Cond. No.                     1.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LWB:
#
#  ********* Significant features in order of impact: Index(['const', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     31.80
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           2.76e-12
# Time:                        18:20:53   Log-Likelihood:                -164.74
# No. Observations:                  62   AIC:                             337.5
# Df Residuals:                      58   BIC:                             346.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.3998      0.080      5.018      0.000       0.240       0.559
# marking             0.0331      0.109      0.302      0.763      -0.186       0.252
# standing_tackle     0.1472      0.084      1.747      0.086      -0.022       0.316
# const              32.0231      4.179      7.662      0.000      23.658      40.389
# ==============================================================================
# Omnibus:                        0.162   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.922   Jarque-Bera (JB):                0.246
# Skew:                           0.115   Prob(JB):                        0.884
# Kurtosis:                       2.793   Cond. No.                     1.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'reactions', 'marking'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     949.7
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          6.85e-299
# Time:                        18:20:53   Log-Likelihood:                -2596.8
# No. Observations:                1057   AIC:                             5202.
# Df Residuals:                    1053   BIC:                             5222.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# reactions           0.2790      0.018     15.830      0.000       0.244       0.314
# marking             0.1154      0.019      6.035      0.000       0.078       0.153
# standing_tackle     0.2938      0.022     13.202      0.000       0.250       0.338
# const              24.3029      0.853     28.496      0.000      22.629      25.976
# ==============================================================================
# Omnibus:                        1.651   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.438   Jarque-Bera (JB):                1.523
# Skew:                           0.064   Prob(JB):                        0.467
# Kurtosis:                       3.134   Cond. No.                     1.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
