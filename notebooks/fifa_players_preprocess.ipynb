# %% [markdown]
# ## Pre-processing
# ### Purpose:

# %%
from fifa_players_functions import *

# %% [markdown]
# ### Load dataset

# %%
from pathlib import Path
# dataset location:
dataset_location = Path('../resources','fifa_world_players_alt.csv')
raw_data = create_fifa_players_dataframe(dataset_location)

# %% [markdown]
# #### encode column labels

# %%
raw_data = raw_data.rename(columns={'Work Rate':'WorkEthic'})
raw_data = encode_field(raw_data, 'WorkEthic')
# raw_data['WorkEthic']

# %% [markdown]
# #### Create goalkeepers dataset

# %%
goal_keepers_data = create_dataset_by_pos(raw_data, 'GK', cols_to_drop_for_keepers, 0)
goal_keepers_data = create_fifa_players_dataset(goal_keepers_data, '../resources/', 'goal_keepers_schema.txt', 'goal_keepers.csv', 0)

display(goal_keepers_data.columns)
# Out:
# e:\data-engineering@ColumbiaUnv\Module-20_final_project\notebooks\fifa_players_functions.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_in['Rating'] = (col.mean(axis=1))
# Index(['ID', 'Name', 'Age', 'Nationality', 'Club', 'Value', 'Wage',
#        'WorkEthic', 'Position', 'Height', 'Weight', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning',
#        'GKReflexes', 'Rating'],
#       dtype='object')

# %% [markdown]
# #### Create players dataset

# %%
players_data = create_dataset_by_pos(raw_data, ' ', cols_to_drop_for_players, 0)
players_data = create_fifa_players_dataset(players_data, '../resources/', 'players_schema.txt', 'players.csv', 0)

display(players_data.columns)
display(players_data.info())
# Out:
# e:\data-engineering@ColumbiaUnv\Module-20_final_project\notebooks\fifa_players_functions.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_in['Rating'] = (col.mean(axis=1))
# Index(['ID', 'Name', 'Age', 'Nationality', 'Club', 'Value', 'Wage',
#        'WorkEthic', 'Position', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'Rating'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17918 entries, 0 to 18206
# Data columns (total 41 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               17918 non-null  int64
#  1   Name             17918 non-null  object
#  2   Age              17918 non-null  int64
#  3   Nationality      17918 non-null  object
#  4   Club             17918 non-null  object
#  5   Value            17918 non-null  object
#  6   Wage             17918 non-null  object
#  7   WorkEthic        17918 non-null  int32
#  8   Position         17918 non-null  object
#  9   Height           17918 non-null  object
#  10  Weight           17918 non-null  object
#  11  Crossing         17918 non-null  float64
#  12  Finishing        17918 non-null  float64
#  13  HeadingAccuracy  17918 non-null  float64
#  14  ShortPassing     17918 non-null  float64
#  15  Volleys          17918 non-null  float64
#  16  Dribbling        17918 non-null  float64
#  17  Curve            17918 non-null  float64
#  18  FKAccuracy       17918 non-null  float64
#  19  LongPassing      17918 non-null  float64
#  20  BallControl      17918 non-null  float64
#  21  Acceleration     17918 non-null  float64
#  22  SprintSpeed      17918 non-null  float64
#  23  Agility          17918 non-null  float64
#  24  Reactions        17918 non-null  float64
#  25  Balance          17918 non-null  float64
#  26  ShotPower        17918 non-null  float64
#  27  Jumping          17918 non-null  float64
#  28  Stamina          17918 non-null  float64
#  29  Strength         17918 non-null  float64
#  30  LongShots        17918 non-null  float64
#  31  Aggression       17918 non-null  float64
#  32  Interceptions    17918 non-null  float64
#  33  Positioning      17918 non-null  float64
#  34  Vision           17918 non-null  float64
#  35  Penalties        17918 non-null  float64
#  36  Composure        17918 non-null  float64
#  37  Marking          17918 non-null  float64
#  38  StandingTackle   17918 non-null  float64
#  39  SlidingTackle    17918 non-null  float64
#  40  Rating           17918 non-null  float64
# dtypes: float64(30), int32(1), int64(2), object(8)
# memory usage: 5.7+ MB
# None

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import style

# %time players_data.hist(bins=40, figsize=(27,17))
plt.show()

# %time goal_keepers_data.hist(bins=40, figsize=(27,17))
plt.show()
# Out:
# Wall time: 929 ms
# Wall time: 760 ms
