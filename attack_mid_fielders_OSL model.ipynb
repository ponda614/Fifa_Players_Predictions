# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
#creat dataframe for the position
file_path ='Resources/attack_mid_fielders.csv'
attack_mid_fielders_df = pd.read_csv(file_path)
attack_mid_fielders_df['rating'] = (attack_mid_fielders_df['potential']+attack_mid_fielders_df['overall'])/2
attack_mid_fielders_df
# Out:
#      overall  potential field_position height  weight  crossing  finishing  \
# 0         89         90            CAM    5'9     161      82.0       90.0
# 1         88         89            LAM   5'11     172      90.0       83.0
# 2         88         91            CAM   5'11     168      88.0       80.0
# 3         86         87            CAM   5'11     168      72.0       87.0
# 4         86         86            CAM    6'1     165      79.0       87.0
# ..       ...        ...            ...    ...     ...       ...        ...
# 995       49         61            CAM    6'0     161      41.0       42.0
# 996       49         59            CAM    6'0     163      40.0       37.0
# 997       49         70            CAM    5'7     137      35.0       32.0
# 998       48         70            CAM   5'11     154      31.0       32.0
# 999       48         48            CAM    5'9     148      51.0       31.0
#
#      heading_accuracy  short_passing  volleys  ...  composure  marking  \
# 0                84.0           83.0     87.0  ...       87.0     59.0
# 1                62.0           89.0     90.0  ...       87.0     52.0
# 2                52.0           91.0     77.0  ...       88.0     59.0
# 3                77.0           86.0     81.0  ...       87.0     60.0
# 4                82.0           83.0     84.0  ...       83.0     44.0
# ..                ...            ...      ...  ...        ...      ...
# 995              40.0           40.0     40.0  ...       49.0     30.0
# 996              38.0           60.0     44.0  ...       56.0     54.0
# 997              35.0           56.0     44.0  ...       58.0     20.0
# 998              48.0           51.0     39.0  ...       41.0     29.0
# 999              37.0           60.0     38.0  ...       62.0     45.0
#
#      standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0               47.0            48.0       14.0          8.0        14.0
# 1               41.0            44.0       15.0         15.0        15.0
# 2               57.0            22.0        9.0         14.0         7.0
# 3               64.0            42.0        8.0         11.0         9.0
# 4               41.0            44.0        6.0          7.0        11.0
# ..               ...             ...        ...          ...         ...
# 995             40.0            40.0       10.0          8.0        14.0
# 996             36.0            43.0        8.0         11.0         7.0
# 997             38.0            41.0       10.0          6.0         9.0
# 998             32.0            40.0       12.0          8.0        11.0
# 999             48.0            42.0       13.0         15.0         7.0
#
#      gk_positioning  gk_reflexes  rating
# 0              13.0         14.0    89.5
# 1               5.0         14.0    88.5
# 2               7.0          6.0    89.5
# 3               6.0         10.0    86.5
# 4              14.0         14.0    86.0
# ..              ...          ...     ...
# 995            11.0         11.0    55.0
# 996            14.0         11.0    54.0
# 997            13.0          6.0    59.5
# 998             9.0         12.0    59.0
# 999            15.0         15.0    48.0
#
# [1000 rows x 40 columns]

# %%
attack_mid_fielders_df.drop(['rating', 'overall', 'potential'], axis = 1).hist(bins=40, figsize=(50,31))
plt.show()

# %%
attack_mid_fielders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   overall           1000 non-null   int64
#  1   potential         1000 non-null   int64
#  2   field_position    1000 non-null   object
#  3   height            1000 non-null   object
#  4   weight            1000 non-null   int64
#  5   crossing          1000 non-null   float64
#  6   finishing         1000 non-null   float64
#  7   heading_accuracy  1000 non-null   float64
#  8   short_passing     1000 non-null   float64
#  9   volleys           1000 non-null   float64
#  10  dribbling         1000 non-null   float64
#  11  curve             1000 non-null   float64
#  12  fk_accuracy       1000 non-null   float64
#  13  long_passing      1000 non-null   float64
#  14  ball_control      1000 non-null   float64
#  15  acceleration      1000 non-null   float64
#  16  sprint_speed      1000 non-null   float64
#  17  agility           1000 non-null   float64
#  18  reactions         1000 non-null   float64
#  19  balance           1000 non-null   float64
#  20  shot_power        1000 non-null   float64
#  21  jumping           1000 non-null   float64
#  22  stamina           1000 non-null   float64
#  23  strength          1000 non-null   float64
#  24  long_shots        1000 non-null   float64
#  25  aggression        1000 non-null   float64
#  26  interceptions     1000 non-null   float64
#  27  positioning       1000 non-null   float64
#  28  vision            1000 non-null   float64
#  29  penalties         1000 non-null   float64
#  30  composure         1000 non-null   float64
#  31  marking           1000 non-null   float64
#  32  standing_tackle   1000 non-null   float64
#  33  sliding_tackle    1000 non-null   float64
#  34  gk_diving         1000 non-null   float64
#  35  gk_handling       1000 non-null   float64
#  36  gk_kicking        1000 non-null   float64
#  37  gk_positioning    1000 non-null   float64
#  38  gk_reflexes       1000 non-null   float64
#  39  rating            1000 non-null   float64
# dtypes: float64(35), int64(3), object(2)
# memory usage: 312.6+ KB

# %%
attack_mid_fielders_df.isna().any()
# Out:
# overall             False
# potential           False
# field_position      False
# height              False
# weight              False
# crossing            False
# finishing           False
# heading_accuracy    False
# short_passing       False
# volleys             False
# dribbling           False
# curve               False
# fk_accuracy         False
# long_passing        False
# ball_control        False
# acceleration        False
# sprint_speed        False
# agility             False
# reactions           False
# balance             False
# shot_power          False
# jumping             False
# stamina             False
# strength            False
# long_shots          False
# aggression          False
# interceptions       False
# positioning         False
# vision              False
# penalties           False
# composure           False
# marking             False
# standing_tackle     False
# sliding_tackle      False
# gk_diving           False
# gk_handling         False
# gk_kicking          False
# gk_positioning      False
# gk_reflexes         False
# rating              False
# dtype: bool

# %%
list(attack_mid_fielders_df)
# Out:
# ['overall',
#  'potential',
#  'field_position',
#  'height',
#  'weight',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'fk_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes',
#  'rating']

# %%
# Define Columns we will include
columns = ['field_position', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'fk_accuracy',
    'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping',
    'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking',
    'standing_tackle', 'sliding_tackle', 'gk_diving','gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'rating']

# Fit columns into df
attack_mid_fielders_df = attack_mid_fielders_df[columns]

#Print df
attack_mid_fielders_df
# Out:
#     field_position  crossing  finishing  heading_accuracy  short_passing  \
# 0              CAM      82.0       90.0              84.0           83.0
# 1              LAM      90.0       83.0              62.0           89.0
# 2              CAM      88.0       80.0              52.0           91.0
# 3              CAM      72.0       87.0              77.0           86.0
# 4              CAM      79.0       87.0              82.0           83.0
# ..             ...       ...        ...               ...            ...
# 995            CAM      41.0       42.0              40.0           40.0
# 996            CAM      40.0       37.0              38.0           60.0
# 997            CAM      35.0       32.0              35.0           56.0
# 998            CAM      31.0       32.0              48.0           51.0
# 999            CAM      51.0       31.0              37.0           60.0
#
#      volleys  dribbling  curve  fk_accuracy  long_passing  ...  composure  \
# 0       87.0       88.0   84.0         78.0          76.0  ...       87.0
# 1       90.0       85.0   89.0         86.0          83.0  ...       87.0
# 2       77.0       84.0   86.0         87.0          88.0  ...       88.0
# 3       81.0       87.0   80.0         65.0          75.0  ...       87.0
# 4       84.0       75.0   81.0         59.0          72.0  ...       83.0
# ..       ...        ...    ...          ...           ...  ...        ...
# 995     40.0       48.0   42.0         36.0          42.0  ...       49.0
# 996     44.0       40.0   47.0         38.0          62.0  ...       56.0
# 997     44.0       40.0   49.0         40.0          52.0  ...       58.0
# 998     39.0       48.0   36.0         37.0          47.0  ...       41.0
# 999     38.0       49.0   45.0         48.0          59.0  ...       62.0
#
#      marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0       59.0             47.0            48.0       14.0          8.0
# 1       52.0             41.0            44.0       15.0         15.0
# 2       59.0             57.0            22.0        9.0         14.0
# 3       60.0             64.0            42.0        8.0         11.0
# 4       44.0             41.0            44.0        6.0          7.0
# ..       ...              ...             ...        ...          ...
# 995     30.0             40.0            40.0       10.0          8.0
# 996     54.0             36.0            43.0        8.0         11.0
# 997     20.0             38.0            41.0       10.0          6.0
# 998     29.0             32.0            40.0       12.0          8.0
# 999     45.0             48.0            42.0       13.0         15.0
#
#      gk_kicking  gk_positioning  gk_reflexes  rating
# 0          14.0            13.0         14.0    89.5
# 1          15.0             5.0         14.0    88.5
# 2           7.0             7.0          6.0    89.5
# 3           9.0             6.0         10.0    86.5
# 4          11.0            14.0         14.0    86.0
# ..          ...             ...          ...     ...
# 995        14.0            11.0         11.0    55.0
# 996         7.0            14.0         11.0    54.0
# 997         9.0            13.0          6.0    59.5
# 998        11.0             9.0         12.0    59.0
# 999         7.0            15.0         15.0    48.0
#
# [1000 rows x 36 columns]

# %%
#Create train_set and test_set
train_set, test_set = train_test_split(attack_mid_fielders_df, test_size=0.2, random_state=42)
print("Length of training data:", len(train_set))
print("Length of testing data:", len(test_set))
print("Length of total data:", len(attack_mid_fielders_df))


target_train = train_set['rating'].values.ravel()
train_set = train_set.drop(['rating'], axis = 1)
# Out:
# Length of training data: 800
# Length of testing data: 200
# Length of total data: 1000

# %%
for position_value in attack_mid_fielders_df['field_position'].unique():
    
    corr_matrix = attack_mid_fielders_df[attack_mid_fielders_df['field_position'] == position_value].corr()['rating'].to_frame()
    temp_df = corr_matrix['rating'].sort_values(ascending=False)
    
    print(f'********** Current Position: {position_value}: \n ')
    
    print(temp_df)
    
    print('\n')

    print(f'-------------------------------------------------------------')
    
    print('\n')
# Out:
# ********** Current Position: CAM:
#
# rating              1.000000
# ball_control        0.872060
# dribbling           0.838879
# short_passing       0.790233
# vision              0.782405
# positioning         0.725088
# reactions           0.716527
# finishing           0.707527
# composure           0.695019
# long_shots          0.692998
# crossing            0.674968
# long_passing        0.668923
# shot_power          0.639851
# curve               0.628656
# volleys             0.625326
# fk_accuracy         0.576096
# penalties           0.512413
# stamina             0.424369
# agility             0.386748
# heading_accuracy    0.299537
# interceptions       0.268432
# acceleration        0.268130
# aggression          0.258747
# marking             0.234805
# strength            0.217625
# sprint_speed        0.216201
# standing_tackle     0.209699
# balance             0.144951
# jumping             0.141014
# sliding_tackle      0.100206
# gk_positioning      0.007101
# gk_reflexes        -0.001049
# gk_diving          -0.001761
# gk_handling        -0.002908
# gk_kicking         -0.013980
# Name: rating, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LAM:
#
# rating              1.000000
# ball_control        0.797582
# short_passing       0.755163
# curve               0.731714
# vision              0.718770
# composure           0.718328
# finishing           0.707135
# reactions           0.702242
# dribbling           0.677890
# crossing            0.668069
# fk_accuracy         0.649283
# volleys             0.607048
# long_shots          0.602153
# positioning         0.584120
# long_passing        0.563935
# gk_reflexes         0.492555
# shot_power          0.433765
# gk_kicking          0.423966
# penalties           0.413841
# gk_handling         0.381251
# aggression          0.349038
# heading_accuracy    0.344592
# sliding_tackle      0.314002
# marking             0.312289
# agility             0.296090
# strength            0.241990
# interceptions       0.227755
# gk_diving           0.216899
# standing_tackle     0.167352
# stamina             0.107495
# acceleration       -0.042925
# jumping            -0.048670
# balance            -0.128571
# sprint_speed       -0.434053
# gk_positioning     -0.464579
# Name: rating, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RAM:
#
# rating              1.000000
# dribbling           0.845509
# ball_control        0.816961
# short_passing       0.804717
# composure           0.736267
# reactions           0.714039
# vision              0.671996
# crossing            0.660216
# positioning         0.653351
# long_passing        0.575264
# curve               0.541566
# shot_power          0.498950
# long_shots          0.462755
# volleys             0.425435
# penalties           0.421530
# fk_accuracy         0.412021
# agility             0.411516
# marking             0.399232
# finishing           0.380619
# interceptions       0.352948
# standing_tackle     0.322708
# gk_kicking          0.321931
# stamina             0.305838
# aggression          0.301995
# sprint_speed        0.294089
# sliding_tackle      0.243555
# gk_reflexes         0.236979
# acceleration        0.225758
# strength            0.212449
# heading_accuracy    0.196924
# balance             0.039071
# gk_positioning     -0.158717
# jumping            -0.306422
# gk_diving          -0.436568
# gk_handling        -0.549067
# Name: rating, dtype: float64
#
#
# -------------------------------------------------------------

# %%
for position in attack_mid_fielders_df['field_position'].unique(): 
    
    try:
    
        # Subset by position
        temp_df = attack_mid_fielders_df[attack_mid_fielders_df['field_position'] == position]
        #temp_df = temp_df.dropna()

        #print(temp_df)
        # Find correlations
        temp_corr = attack_mid_fielders_df[attack_mid_fielders_df['field_position'] == position].corr()['rating'].to_frame()
        temp_corr = temp_corr[temp_corr['rating'] > 0.5]


        # Keep only columns with correltion above 0.5
        temp_features = list(temp_corr.T)
        temp_model_df = temp_df[temp_features]

        #print(temp_features)
        # Split data into train and test, isolate y (target/dependent variable)
        train_set, test_set = train_test_split(temp_model_df, test_size=0.2, random_state=42)
        target_train = train_set['rating']
        train_set = train_set.drop(['rating'], axis = 1) #, 'potential', 'overall'], axis = 1)
        

        # Fit model
        train_set = sm.add_constant(train_set, prepend=False)

        # Fit and summarize OLS model
        mod = sm.OLS(target_train, train_set)

        res = mod.fit()
        
        features = pd.DataFrame([res.pvalues, res.params]).T
        features.columns = ['P-value', 'Coefficient']
        features = features[features['P-value']<0.05]
        features = features.sort_values(by = 'Coefficient', ascending = False)
    

        print(f' ********* Current Position: {position}: \n ')
        print(f' ********* Significant features in order of impact: {features.index}: \n ')
        print(res.summary())
        print('\n')
        
    except BaseException as e: 
        print(f'WARNING: SKIPPING {position} due to {e}')
# Out:
#  ********* Current Position: CAM:
#
#  ********* Significant features in order of impact: Index(['const', 'dribbling', 'ball_control', 'short_passing', 'vision',
#        'finishing', 'volleys', 'crossing', 'penalties'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     211.3
# Date:                Fri, 16 Jul 2021   Prob (F-statistic):          1.09e-264
# Time:                        21:28:09   Log-Likelihood:                -1803.0
# No. Observations:                 766   AIC:                             3640.
# Df Residuals:                     749   BIC:                             3719.
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# crossing         -0.0378      0.017     -2.290      0.022      -0.070      -0.005
# finishing         0.0761      0.018      4.198      0.000       0.041       0.112
# short_passing     0.1717      0.030      5.699      0.000       0.113       0.231
# volleys          -0.0289      0.015     -1.974      0.049      -0.058      -0.000
# dribbling         0.2231      0.027      8.388      0.000       0.171       0.275
# curve             0.0085      0.015      0.554      0.580      -0.022       0.039
# fk_accuracy      -0.0109      0.013     -0.816      0.415      -0.037       0.015
# long_passing      0.0088      0.023      0.384      0.701      -0.036       0.054
# ball_control      0.2157      0.036      5.931      0.000       0.144       0.287
# reactions         0.0282      0.019      1.511      0.131      -0.008       0.065
# shot_power        0.0162      0.018      0.912      0.362      -0.019       0.051
# long_shots       -0.0160      0.017     -0.952      0.341      -0.049       0.017
# positioning       0.0145      0.019      0.755      0.451      -0.023       0.052
# vision            0.1015      0.022      4.517      0.000       0.057       0.146
# penalties        -0.0406      0.013     -3.044      0.002      -0.067      -0.014
# composure         0.0093      0.018      0.517      0.606      -0.026       0.045
# const            19.5199      1.024     19.068      0.000      17.510      21.530
# ==============================================================================
# Omnibus:                      281.350   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3538.467
# Skew:                           1.288   Prob(JB):                         0.00
# Kurtosis:                      13.209   Cond. No.                     2.78e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LAM:
#
#  ********* Significant features in order of impact: Index([], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     2.168
# Date:                Fri, 16 Jul 2021   Prob (F-statistic):              0.492
# Time:                        21:28:09   Log-Likelihood:                -5.3558
# No. Observations:                  16   AIC:                             40.71
# Df Residuals:                       1   BIC:                             52.30
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# crossing         -0.5305      0.400     -1.327      0.411      -5.612       4.551
# finishing         0.5588      0.317      1.761      0.329      -3.474       4.592
# short_passing    -2.7625      2.626     -1.052      0.484     -36.126      30.601
# volleys          -0.2527      0.304     -0.832      0.558      -4.109       3.604
# dribbling         1.2160      0.868      1.401      0.395      -9.815      12.247
# curve             0.4500      0.306      1.469      0.380      -3.442       4.342
# fk_accuracy       0.0615      0.104      0.590      0.661      -1.261       1.384
# long_passing      0.8116      0.645      1.258      0.427      -7.383       9.006
# ball_control      0.8770      1.175      0.747      0.592     -14.047      15.802
# reactions         0.7452      0.504      1.478      0.379      -5.662       7.152
# long_shots       -0.1411      0.135     -1.043      0.486      -1.860       1.578
# positioning      -1.1406      0.994     -1.148      0.456     -13.769      11.488
# vision            0.6839      0.723      0.946      0.518      -8.507       9.874
# composure        -0.1967      0.204     -0.966      0.511      -2.783       2.390
# const            45.0389     14.206      3.170      0.195    -135.470     225.547
# ==============================================================================
# Omnibus:                        1.549   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.126
# Skew:                          -0.614   Prob(JB):                        0.569
# Kurtosis:                       2.572   Cond. No.                     1.04e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RAM:
#
#  ********* Significant features in order of impact: Index(['ball_control', 'short_passing'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     12.93
# Date:                Fri, 16 Jul 2021   Prob (F-statistic):            0.00563
# Time:                        21:28:09   Log-Likelihood:                -11.096
# No. Observations:                  16   AIC:                             44.19
# Df Residuals:                       5   BIC:                             52.69
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# crossing         -0.1376      0.106     -1.294      0.252      -0.411       0.136
# short_passing     0.3183      0.108      2.948      0.032       0.041       0.596
# dribbling         0.1244      0.138      0.901      0.409      -0.230       0.479
# curve             0.0466      0.039      1.187      0.289      -0.054       0.147
# long_passing      0.0811      0.037      2.187      0.080      -0.014       0.176
# ball_control      0.4863      0.171      2.837      0.036       0.046       0.927
# reactions         0.1569      0.123      1.278      0.258      -0.159       0.473
# positioning       0.2428      0.156      1.553      0.181      -0.159       0.645
# vision           -0.1216      0.079     -1.544      0.183      -0.324       0.081
# composure        -0.0947      0.079     -1.207      0.282      -0.297       0.107
# const            -6.6687     10.112     -0.659      0.539     -32.662      19.324
# ==============================================================================
# Omnibus:                        3.919   Durbin-Watson:                   1.613
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.194
# Skew:                          -0.901   Prob(JB):                        0.334
# Kurtosis:                       3.206   Cond. No.                     1.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\User\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# C:\Users\User\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
