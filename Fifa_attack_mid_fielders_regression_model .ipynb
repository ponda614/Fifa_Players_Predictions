# %%
# %run s0_fifa_players_functions.ipynb

# %%
goal_keepers = 'GK'
defenders = 'RWB', 'RCB', 'RB', 'LCB', 'CB', 'LWB', 'LB'
def_mid_fielders = 'LDM', 'CDM','RDM'
mid_fielders = 'CM', 'RCM', 'RM', 'LCM', 'LM'
attack_mid_fielders = 'LAM', 'CAM', 'RAM'
forwards = 'RF', 'CF','LF', 'LW', 'RW'
strikers = 'ST', 'RS', 'LS'

# %%
# Connect to DB
conn, cursor= connect()

import pandas
# sql = """ SELECT * from players where field_position in ('GK') """
sql = f"SELECT * from players where field_position in {attack_mid_fielders} "

attack_mid_fielders_data = pandas.read_sql(sql, con=conn)
# conn.commit()

# Disconnect from DB
disconnect(conn, cursor)

attack_mid_fielders_data = create_players_dataframes(attack_mid_fielders_data, columns_to_keep)
# display(goal_keepers_data)
attack_mid_fielders_data = create_fifa_players_dataset(attack_mid_fielders_data, "Resources/", "attack_mid_fielders.csv")
# Out:
# Connected!
# Wall time: 39 ms

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import statsmodels.api as sm

# %%
file_path ='Resources/mid_fielders.csv'
attack_mid_fielders_df = pd.read_csv(file_path)
attack_mid_fielders_df['rating'] = (attack_mid_fielders_df['potential']+attack_mid_fielders_df['overall'])/2
attack_mid_fielders_df
# Out:
#       overall  potential field_position height  weight  crossing  finishing  \
# 0          91         92            RCM   5'11     154      93.0       82.0
# 1          91         91            RCM    5'8     146      86.0       72.0
# 2          90         90            LCM    6'0     168      88.0       76.0
# 3          90         90            LCM    5'8     148      84.0       76.0
# 4          88         95             RM   5'10     161      77.0       88.0
# ...       ...        ...            ...    ...     ...       ...        ...
# 4394       47         61             CM    5'7     146      31.0       28.0
# 4395       47         61             CM   5'10     141      44.0       44.0
# 4396       47         69             CM    5'6     150      31.0       31.0
# 4397       47         65             CM    5'9     134      34.0       38.0
# 4398       46         66             CM   5'10     176      41.0       34.0
#
#       heading_accuracy  short_passing  volleys  ...  composure  marking  \
# 0                 55.0           92.0     82.0  ...       88.0     68.0
# 1                 55.0           93.0     76.0  ...       84.0     60.0
# 2                 54.0           92.0     82.0  ...       85.0     72.0
# 3                 54.0           93.0     82.0  ...       93.0     59.0
# 4                 77.0           82.0     78.0  ...       86.0     34.0
# ...                ...            ...      ...  ...        ...      ...
# 4394              40.0           53.0     31.0  ...       35.0     41.0
# 4395              36.0           53.0     43.0  ...       52.0     41.0
# 4396              41.0           51.0     26.0  ...       40.0     48.0
# 4397              40.0           49.0     25.0  ...       45.0     40.0
# 4398              46.0           48.0     30.0  ...       43.0     40.0
#
#       standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0                58.0            51.0       15.0         13.0         5.0
# 1                76.0            73.0       13.0          9.0         7.0
# 2                79.0            69.0       10.0         11.0        13.0
# 3                53.0            29.0        6.0         15.0         7.0
# 4                34.0            32.0       13.0          5.0         7.0
# ...               ...             ...        ...          ...         ...
# 4394             44.0            54.0       10.0         12.0         6.0
# 4395             47.0            38.0       13.0          6.0         9.0
# 4396             49.0            49.0        7.0          7.0         9.0
# 4397             48.0            47.0       10.0         13.0         7.0
# 4398             43.0            50.0       10.0         15.0         9.0
#
#       gk_positioning  gk_reflexes  rating
# 0               10.0         13.0    91.5
# 1               14.0          9.0    91.0
# 2                7.0         10.0    90.0
# 3                6.0         12.0    90.0
# 4               11.0          6.0    91.5
# ...              ...          ...     ...
# 4394            11.0          8.0    54.0
# 4395            10.0         15.0    54.0
# 4396            14.0         15.0    58.0
# 4397             8.0          9.0    56.0
# 4398            12.0          9.0    56.0
#
# [4399 rows x 40 columns]

# %%
list(attack_mid_fielders_df)
# Out:
# ['overall',
#  'potential',
#  'field_position',
#  'height',
#  'weight',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'fk_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes',
#  'rating']

# %%
columns = ['field_position','height', 'weight', 'crossing', 'finishing', 'heading_accuracy',
           'short_passing', 'volleys', 'dribbling', 'curve', 'fk_accuracy', 'long_passing',
           'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
           'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
           'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking',
           'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking',
           'gk_positioning', 'gk_reflexes', 'rating']

attack_mid_fielders_df = attack_mid_fielders_df[columns]

attack_mid_fielders_df
# Out:
#      field_position height  weight  crossing  finishing  heading_accuracy  \
# 0               RCM   5'11     154      93.0       82.0              55.0
# 1               RCM    5'8     146      86.0       72.0              55.0
# 2               LCM    6'0     168      88.0       76.0              54.0
# 3               LCM    5'8     148      84.0       76.0              54.0
# 4                RM   5'10     161      77.0       88.0              77.0
# ...             ...    ...     ...       ...        ...               ...
# 4394             CM    5'7     146      31.0       28.0              40.0
# 4395             CM   5'10     141      44.0       44.0              36.0
# 4396             CM    5'6     150      31.0       31.0              41.0
# 4397             CM    5'9     134      34.0       38.0              40.0
# 4398             CM   5'10     176      41.0       34.0              46.0
#
#       short_passing  volleys  dribbling  curve  ...  composure  marking  \
# 0              92.0     82.0       86.0   85.0  ...       88.0     68.0
# 1              93.0     76.0       90.0   85.0  ...       84.0     60.0
# 2              92.0     82.0       81.0   86.0  ...       85.0     72.0
# 3              93.0     82.0       89.0   82.0  ...       93.0     59.0
# 4              82.0     78.0       90.0   77.0  ...       86.0     34.0
# ...             ...      ...        ...    ...  ...        ...      ...
# 4394           53.0     31.0       46.0   39.0  ...       35.0     41.0
# 4395           53.0     43.0       50.0   48.0  ...       52.0     41.0
# 4396           51.0     26.0       46.0   35.0  ...       40.0     48.0
# 4397           49.0     25.0       42.0   30.0  ...       45.0     40.0
# 4398           48.0     30.0       43.0   40.0  ...       43.0     40.0
#
#       standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0                58.0            51.0       15.0         13.0         5.0
# 1                76.0            73.0       13.0          9.0         7.0
# 2                79.0            69.0       10.0         11.0        13.0
# 3                53.0            29.0        6.0         15.0         7.0
# 4                34.0            32.0       13.0          5.0         7.0
# ...               ...             ...        ...          ...         ...
# 4394             44.0            54.0       10.0         12.0         6.0
# 4395             47.0            38.0       13.0          6.0         9.0
# 4396             49.0            49.0        7.0          7.0         9.0
# 4397             48.0            47.0       10.0         13.0         7.0
# 4398             43.0            50.0       10.0         15.0         9.0
#
#       gk_positioning  gk_reflexes  rating
# 0               10.0         13.0    91.5
# 1               14.0          9.0    91.0
# 2                7.0         10.0    90.0
# 3                6.0         12.0    90.0
# 4               11.0          6.0    91.5
# ...              ...          ...     ...
# 4394            11.0          8.0    54.0
# 4395            10.0         15.0    54.0
# 4396            14.0         15.0    58.0
# 4397             8.0          9.0    56.0
# 4398            12.0          9.0    56.0
#
# [4399 rows x 38 columns]

# %%
attack_mid_fielders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4399 entries, 0 to 4398
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field_position    4399 non-null   object
#  1   height            4399 non-null   object
#  2   weight            4399 non-null   int64
#  3   crossing          4399 non-null   float64
#  4   finishing         4399 non-null   float64
#  5   heading_accuracy  4399 non-null   float64
#  6   short_passing     4399 non-null   float64
#  7   volleys           4399 non-null   float64
#  8   dribbling         4399 non-null   float64
#  9   curve             4399 non-null   float64
#  10  fk_accuracy       4399 non-null   float64
#  11  long_passing      4399 non-null   float64
#  12  ball_control      4399 non-null   float64
#  13  acceleration      4399 non-null   float64
#  14  sprint_speed      4399 non-null   float64
#  15  agility           4399 non-null   float64
#  16  reactions         4399 non-null   float64
#  17  balance           4399 non-null   float64
#  18  shot_power        4399 non-null   float64
#  19  jumping           4399 non-null   float64
#  20  stamina           4399 non-null   float64
#  21  strength          4399 non-null   float64
#  22  long_shots        4399 non-null   float64
#  23  aggression        4399 non-null   float64
#  24  interceptions     4399 non-null   float64
#  25  positioning       4399 non-null   float64
#  26  vision            4399 non-null   float64
#  27  penalties         4399 non-null   float64
#  28  composure         4399 non-null   float64
#  29  marking           4399 non-null   float64
#  30  standing_tackle   4399 non-null   float64
#  31  sliding_tackle    4399 non-null   float64
#  32  gk_diving         4399 non-null   float64
#  33  gk_handling       4399 non-null   float64
#  34  gk_kicking        4399 non-null   float64
#  35  gk_positioning    4399 non-null   float64
#  36  gk_reflexes       4399 non-null   float64
#  37  rating            4399 non-null   float64
# dtypes: float64(35), int64(1), object(2)
# memory usage: 1.3+ MB

# %%
attack_mid_fielders_df.isna().any()
# Out:
# field_position      False
# height              False
# weight              False
# crossing            False
# finishing           False
# heading_accuracy    False
# short_passing       False
# volleys             False
# dribbling           False
# curve               False
# fk_accuracy         False
# long_passing        False
# ball_control        False
# acceleration        False
# sprint_speed        False
# agility             False
# reactions           False
# balance             False
# shot_power          False
# jumping             False
# stamina             False
# strength            False
# long_shots          False
# aggression          False
# interceptions       False
# positioning         False
# vision              False
# penalties           False
# composure           False
# marking             False
# standing_tackle     False
# sliding_tackle      False
# gk_diving           False
# gk_handling         False
# gk_kicking          False
# gk_positioning      False
# gk_reflexes         False
# rating              False
# dtype: bool

# %%
corr_matrix = attack_mid_fielders_df.corr()
corr_matrix['rating'].sort_values(ascending=False)
# Out:
# rating              1.000000
# ball_control        0.877423
# dribbling           0.825635
# short_passing       0.769826
# vision              0.757455
# reactions           0.745510
# composure           0.727828
# positioning         0.697166
# long_shots          0.664420
# crossing            0.644424
# shot_power          0.631903
# long_passing        0.618726
# curve               0.605818
# finishing           0.602825
# volleys             0.558764
# fk_accuracy         0.486963
# penalties           0.466502
# stamina             0.428567
# agility             0.376979
# heading_accuracy    0.332194
# aggression          0.295261
# interceptions       0.293526
# acceleration        0.289412
# marking             0.278575
# sprint_speed        0.251743
# standing_tackle     0.240853
# strength            0.207798
# balance             0.193368
# sliding_tackle      0.188668
# jumping             0.142092
# weight              0.100897
# gk_kicking          0.047863
# gk_reflexes         0.023338
# gk_positioning      0.017064
# gk_handling         0.013631
# gk_diving          -0.001895
# Name: rating, dtype: float64

# %%
for position in attack_mid_fielders_df['field_position'].unique():
    
        try:
            # Subset by position
            temp_df = attack_mid_fielders_df[attack_mid_fielders_df["field_position"] == position]
            #temp_df = temp_df.dropna()
        
            # Find correlations
            temp_corr = attack_mid_fielders_df.corr()['rating'].to_frame()
            temp_corr = temp_corr[temp_corr['rating'] > 0.7]
            
            # Keep only columns with correltion above 0.7
            temp_features = list(temp_corr.T)
            temp_model_df = temp_df[temp_features]

            # Split data into train and test, isolate y (target/dependent variable)
            train_set, test_set = train_test_split(temp_model_df, test_size=0.2, random_state=42)
            target_train = train_set['rating']
            train_set = train_set.drop(['rating'], axis= 1) #'potential', 'overall'], axis = 1)
            
            # Fit model
            train_set = sm.add_constant(train_set, prepend=False)
            
            # Fit and summarize OLS model
            mod = sm.OLS(target_train, train_set)
            res = mod.fit()
            features = pd.DataFrame([res.pvalues, res.params]).T
            features.columns = ['P-value', 'Coefficient']
            features = features[features['P-value']<0.05]
            features = features.sort_values(by = 'Coefficient', ascending = False)
            
            
            print(f' ********* Current Position: {position}: \n ')
            print(f' ********* Significant features in order of impact: {features.index}: \n ')
            print(res.summary())
            print('\n')
       
        except BaseException as e:
            print(f'WARNING: SKIPPING {position} due to {e}')
# Out:
#  ********* Current Position: RCM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'reactions', 'ball_control', 'dribbling'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     219.0
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          2.15e-107
# Time:                        19:31:15   Log-Likelihood:                -727.77
# No. Observations:                 312   AIC:                             1470.
# Df Residuals:                     305   BIC:                             1496.
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# short_passing     0.3804      0.046      8.236      0.000       0.290       0.471
# dribbling         0.1193      0.038      3.120      0.002       0.044       0.195
# ball_control      0.1548      0.058      2.674      0.008       0.041       0.269
# reactions         0.1760      0.033      5.406      0.000       0.112       0.240
# vision           -0.0391      0.032     -1.218      0.224      -0.102       0.024
# composure         0.0281      0.026      1.088      0.277      -0.023       0.079
# const            14.2885      1.589      8.990      0.000      11.161      17.416
# ==============================================================================
# Omnibus:                        9.265   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.108
# Skew:                           0.380   Prob(JB):                       0.0105
# Kurtosis:                       2.647   Cond. No.                     1.84e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LCM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'ball_control', 'reactions', 'dribbling'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     230.3
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          7.45e-111
# Time:                        19:31:16   Log-Likelihood:                -728.00
# No. Observations:                 316   AIC:                             1470.
# Df Residuals:                     309   BIC:                             1496.
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# short_passing     0.3395      0.048      7.029      0.000       0.244       0.435
# dribbling         0.1287      0.037      3.504      0.001       0.056       0.201
# ball_control      0.1944      0.055      3.544      0.000       0.086       0.302
# reactions         0.1469      0.028      5.311      0.000       0.093       0.201
# vision           -0.0508      0.031     -1.640      0.102      -0.112       0.010
# composure         0.0486      0.025      1.919      0.056      -0.001       0.098
# const            15.2711      1.586      9.629      0.000      12.150      18.392
# ==============================================================================
# Omnibus:                        9.040   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.131
# Skew:                           0.414   Prob(JB):                       0.0104
# Kurtosis:                       3.094   Cond. No.                     1.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RM:
#
#  ********* Significant features in order of impact: Index(['const', 'dribbling', 'ball_control', 'short_passing', 'reactions',
#        'vision'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     689.1
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        19:31:16   Log-Likelihood:                -2094.1
# No. Observations:                 899   AIC:                             4202.
# Df Residuals:                     892   BIC:                             4236.
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# short_passing     0.1114      0.021      5.291      0.000       0.070       0.153
# dribbling         0.2866      0.025     11.569      0.000       0.238       0.335
# ball_control      0.2187      0.031      7.152      0.000       0.159       0.279
# reactions         0.0554      0.015      3.651      0.000       0.026       0.085
# vision            0.0406      0.017      2.440      0.015       0.008       0.073
# composure         0.0097      0.015      0.628      0.530      -0.021       0.040
# const            21.3625      0.778     27.472      0.000      19.836      22.889
# ==============================================================================
# Omnibus:                       26.083   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.431
# Skew:                           0.278   Prob(JB):                     7.45e-09
# Kurtosis:                       3.831   Cond. No.                     1.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LM:
#
#  ********* Significant features in order of impact: Index(['const', 'dribbling', 'ball_control', 'short_passing', 'reactions'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     593.1
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):          3.32e-303
# Time:                        19:31:16   Log-Likelihood:                -2058.2
# No. Observations:                 876   AIC:                             4130.
# Df Residuals:                     869   BIC:                             4164.
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# short_passing     0.1212      0.021      5.732      0.000       0.080       0.163
# dribbling         0.2740      0.027     10.338      0.000       0.222       0.326
# ball_control      0.2268      0.032      7.059      0.000       0.164       0.290
# reactions         0.0636      0.015      4.162      0.000       0.034       0.094
# vision            0.0212      0.018      1.189      0.235      -0.014       0.056
# composure         0.0144      0.015      0.937      0.349      -0.016       0.045
# const            21.3239      0.839     25.417      0.000      19.677      22.971
# ==============================================================================
# Omnibus:                       26.633   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.502
# Skew:                           0.411   Prob(JB):                     6.47e-07
# Kurtosis:                       3.324   Cond. No.                     1.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'dribbling', 'ball_control', 'reactions',
#        'vision'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     1026.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        19:31:16   Log-Likelihood:                -2576.5
# No. Observations:                1115   AIC:                             5167.
# Df Residuals:                    1108   BIC:                             5202.
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# short_passing     0.3323      0.021     15.625      0.000       0.291       0.374
# dribbling         0.1738      0.020      8.670      0.000       0.134       0.213
# ball_control      0.1245      0.026      4.812      0.000       0.074       0.175
# reactions         0.0942      0.015      6.393      0.000       0.065       0.123
# vision            0.0840      0.016      5.093      0.000       0.052       0.116
# composure        -0.0102      0.012     -0.813      0.416      -0.035       0.014
# const            15.5151      0.735     21.116      0.000      14.073      16.957
# ==============================================================================
# Omnibus:                        4.999   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                4.638
# Skew:                           0.109   Prob(JB):                       0.0984
# Kurtosis:                       2.772   Cond. No.                     1.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
