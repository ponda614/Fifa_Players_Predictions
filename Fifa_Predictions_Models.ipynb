# %%
# import sys
# sys.path.append('..')

import os

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# from src.analysis import plot_categoric_attribute, plot_discrete_attribute
# from src.helpers import get_numeric_columns

# %%
# %run 1st_Functions.ipynb

# %%
# Connect to DB
conn, cursor= connect()

import pandas
# sql = """ SELECT * from players where field_position in ('GK') """
sql = f"SELECT * from players"

data = pandas.read_sql(sql, con=conn)
# conn.commit()

# Disconnect from DB
disconnect(conn, cursor)

# data = create_players_dataframes(data, columns_to_keep)
# display(data)
display(data.shape)
# goal_keepers_data = create_fifa_players_dataset(goal_keepers_data, './resources/', 'goal_keepers.csv')
# Out:
# <connection object at 0x00000209369E9150; dsn: 'user=postgres password=xxx dbname=fifa-players-prediction host=fifa-players-prediction.c05nwfquwc6t.us-east-1.rds.amazonaws.com port=5432', closed: 0>
# Connected!
# (18147, 88)

# %% [markdown]
# ## Data structure
# |columns|rows|
# |--|--|
# |88|18159|

# %%
# https://github.com/ResidentMario/missingno
# !pip install missingno
# file_path ='resources/fifa_world_players_alt.csv'
# data = pd.read_csv(file_path)


import missingno as msno
plot_count = 1
column_groups = np.array_split(data.columns, plot_count)

for columns in column_groups:
    msno.bar(data[columns])
    plt.show()

# %%
print(data.shape)
# display(data.head())
data.info()
# Out:
# (18147, 88)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18147 entries, 0 to 18146
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_id                 18147 non-null  int64
#  1   player_name               18147 non-null  object
#  2   age                       18147 non-null  float64
#  3   photo                     18147 non-null  object
#  4   nationality               18147 non-null  object
#  5   country_flag              18147 non-null  object
#  6   overall                   18147 non-null  float64
#  7   potential                 18147 non-null  float64
#  8   club                      18147 non-null  object
#  9   club_logo                 18147 non-null  object
#  10  contract_value            18147 non-null  object
#  11  wage                      18147 non-null  object
#  12  special                   18147 non-null  object
#  13  preferred_foot            18147 non-null  object
#  14  international_reputation  18147 non-null  object
#  15  weak_foot                 18147 non-null  object
#  16  skills_moves              18147 non-null  object
#  17  work_rate                 18147 non-null  object
#  18  body_type                 18147 non-null  object
#  19  real_face                 18147 non-null  object
#  20  field_position            18147 non-null  object
#  21  jersey_number             18147 non-null  object
#  22  joined                    18147 non-null  object
#  23  loaned_from               18147 non-null  object
#  24  contract_valid_until      18147 non-null  object
#  25  height                    18147 non-null  object
#  26  weight                    18147 non-null  object
#  27  ls                        18147 non-null  object
#  28  st                        18147 non-null  object
#  29  rs                        18147 non-null  object
#  30  lw                        18147 non-null  object
#  31  lf                        18147 non-null  object
#  32  cf                        18147 non-null  object
#  33  rf                        18147 non-null  object
#  34  rw                        18147 non-null  object
#  35  lam                       18147 non-null  object
#  36  cam                       18147 non-null  object
#  37  ram                       18147 non-null  object
#  38  lm                        18147 non-null  object
#  39  lcm                       18147 non-null  object
#  40  cm                        18147 non-null  object
#  41  rcm                       18147 non-null  object
#  42  rm                        18147 non-null  object
#  43  lwb                       18147 non-null  object
#  44  ldm                       18147 non-null  object
#  45  cdm                       18147 non-null  object
#  46  rdm                       18147 non-null  object
#  47  rwb                       18147 non-null  object
#  48  lb                        18147 non-null  object
#  49  lcb                       18147 non-null  object
#  50  cb                        18147 non-null  object
#  51  rcb                       18147 non-null  object
#  52  rb                        18147 non-null  object
#  53  crossing                  18147 non-null  int64
#  54  finishing                 18147 non-null  int64
#  55  heading_accuracy          18147 non-null  int64
#  56  short_passing             18147 non-null  int64
#  57  volleys                   18147 non-null  int64
#  58  dribbling                 18147 non-null  int64
#  59  curve                     18147 non-null  int64
#  60  fk_accuracy               18147 non-null  int64
#  61  long_passing              18147 non-null  int64
#  62  ball_control              18147 non-null  int64
#  63  acceleration              18147 non-null  int64
#  64  sprint_speed              18147 non-null  int64
#  65  agility                   18147 non-null  int64
#  66  reactions                 18147 non-null  int64
#  67  balance                   18147 non-null  int64
#  68  shot_power                18147 non-null  int64
#  69  jumping                   18147 non-null  int64
#  70  stamina                   18147 non-null  int64
#  71  strength                  18147 non-null  int64
#  72  long_shots                18147 non-null  int64
#  73  aggression                18147 non-null  int64
#  74  interceptions             18147 non-null  int64
#  75  positioning               18147 non-null  int64
#  76  vision                    18147 non-null  int64
#  77  penalties                 18147 non-null  int64
#  78  composure                 18147 non-null  int64
#  79  marking                   18147 non-null  int64
#  80  standing_tackle           18147 non-null  int64
#  81  sliding_tackle            18147 non-null  int64
#  82  gk_diving                 18147 non-null  int64
#  83  gk_handling               18147 non-null  int64
#  84  gk_kicking                18147 non-null  int64
#  85  gk_positioning            18147 non-null  int64
#  86  gk_reflexes               18147 non-null  int64
#  87  release_clause            18147 non-null  object
# dtypes: float64(3), int64(35), object(50)
# memory usage: 12.2+ MB

# %%
data.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'photo', 'nationality',
#        'country_flag', 'overall', 'potential', 'club', 'club_logo',
#        'contract_value', 'wage', 'special', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skills_moves', 'work_rate',
#        'body_type', 'real_face', 'field_position', 'jersey_number', 'joined',
#        'loaned_from', 'contract_valid_until', 'height', 'weight', 'ls', 'st',
#        'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm',
#        'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
#        'rcb', 'rb', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'fk_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_positioning', 'gk_reflexes', 'release_clause'],
#       dtype='object')

# %%
data.drop(['ls', 'st',
       'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm',
       'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
       'rcb', 'rb'], axis =1, inplace = True)
data.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'photo', 'nationality',
#        'country_flag', 'overall', 'potential', 'club', 'club_logo',
#        'contract_value', 'wage', 'special', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skills_moves', 'work_rate',
#        'body_type', 'real_face', 'field_position', 'jersey_number', 'joined',
#        'loaned_from', 'contract_valid_until', 'height', 'weight', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control',
#        'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
#        'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes', 'release_clause'],
#       dtype='object')

# %%
plt.figure(figsize = (20,10))
sns.violinplot(x="age",y = "overall", data = data)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create position class

# %%
keepers = []
defenders = []
mid_fielders = []
forwards = []
position_class = data['field_position'].unique()
position_class[-1] = 'unknown'


for label in position_class:
    if(label[-1] == 'K'):
        keepers.append(label)
    if(label[-1] == 'M'):
        mid_fielders.append(label)
    elif(label[-1] =='B'):
        defenders.append(label)
    elif(label[-1] in 'T', 'F', 'S'):
        forwards.append(label)
    else: pass

# %store keepers
# %store defenders
# %store mid_fielders
# %store forwards

print(position_class)
print(f"\n{defenders}")
print(f"\n{keepers}")
print(f"\n{mid_fielders}")
print(f"\n{forwards}")
# Out:
# Stored 'keepers' (list)
# Stored 'defenders' (list)
# Stored 'mid_fielders' (list)
# Stored 'forwards' (list)
# ['RF' 'ST' 'LW' 'GK' 'RCM' 'LF' 'RS' 'RCB' 'LCM' 'CB' 'LDM' 'CAM' 'CDM'
#  'LS' 'LCB' 'RM' 'LAM' 'LM' 'LB' 'RDM' 'RW' 'CM' 'RB' 'RAM' 'CF' 'RWB'
#  'unknown']
#
# ['RCB', 'CB', 'LCB', 'LB', 'RB', 'RWB']
#
# ['GK']
#
# ['RCM', 'LCM', 'LDM', 'CAM', 'CDM', 'RM', 'LAM', 'LM', 'RDM', 'CM', 'RAM']
#
# ['RF', 'ST', 'LW', 'GK', 'LF', 'RS', 'LS', 'RW', 'CF', 'unknown']

# %% [markdown]
# ## Relevance of Qualitative Features to Rating

# %%
data.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'photo', 'nationality',
#        'country_flag', 'overall', 'potential', 'club', 'club_logo',
#        'contract_value', 'wage', 'special', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skills_moves', 'work_rate',
#        'body_type', 'real_face', 'field_position', 'jersey_number', 'joined',
#        'loaned_from', 'contract_valid_until', 'height', 'weight', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'fk_accuracy', 'long_passing', 'ball_control',
#        'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
#        'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes', 'release_clause'],
#       dtype='object')

# %%
target_vals = ['standing_tackle', 'marking', 'interceptions', 'heading_accuracy', 'sliding_tackle', 'short_passing']
# print(target_vals)
fig = plt.figure(figsize = (15,20))

for i, feature in enumerate(target_vals):
    # print(feature)
    # print(data.groupby([feature]).mean()["overall"])
    ax = fig.add_subplot(3,2,i+1)
    data.groupby([feature]).mean()["overall"].sort_values(ascending=False)[0:25].plot(kind="bar")
    ax.set_ylabel("overall")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quant Features against Rating

# %%
from sklearn.preprocessing import scale
from sklearn.feature_selection import RFE
from sklearn.linear_model import Ridge, Lasso, LinearRegression
df_vals = data.select_dtypes(["int64", 'float64'])
df_vals = df_vals.drop("overall", axis = 1)
rating = data["overall"]
df_vals.info()


X = df_vals.values
X = scale(X)
y = rating.values.ravel()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18147 entries, 0 to 18146
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   player_id         18147 non-null  int64
#  1   age               18147 non-null  float64
#  2   potential         18147 non-null  float64
#  3   crossing          18147 non-null  int64
#  4   finishing         18147 non-null  int64
#  5   heading_accuracy  18147 non-null  int64
#  6   short_passing     18147 non-null  int64
#  7   volleys           18147 non-null  int64
#  8   dribbling         18147 non-null  int64
#  9   curve             18147 non-null  int64
#  10  fk_accuracy       18147 non-null  int64
#  11  long_passing      18147 non-null  int64
#  12  ball_control      18147 non-null  int64
#  13  acceleration      18147 non-null  int64
#  14  sprint_speed      18147 non-null  int64
#  15  agility           18147 non-null  int64
#  16  reactions         18147 non-null  int64
#  17  balance           18147 non-null  int64
#  18  shot_power        18147 non-null  int64
#  19  jumping           18147 non-null  int64
#  20  stamina           18147 non-null  int64
#  21  strength          18147 non-null  int64
#  22  long_shots        18147 non-null  int64
#  23  aggression        18147 non-null  int64
#  24  interceptions     18147 non-null  int64
#  25  positioning       18147 non-null  int64
#  26  vision            18147 non-null  int64
#  27  penalties         18147 non-null  int64
#  28  composure         18147 non-null  int64
#  29  marking           18147 non-null  int64
#  30  standing_tackle   18147 non-null  int64
#  31  sliding_tackle    18147 non-null  int64
#  32  gk_diving         18147 non-null  int64
#  33  gk_handling       18147 non-null  int64
#  34  gk_kicking        18147 non-null  int64
#  35  gk_positioning    18147 non-null  int64
#  36  gk_reflexes       18147 non-null  int64
# dtypes: float64(2), int64(35)
# memory usage: 5.1 MB

# %%
fig = plt.figure(figsize = (15,60))
for idx in range(37):
    feature = df_vals.columns[idx]
    ax = fig.add_subplot(13,3,idx+1)
    Xtmp = df_vals[feature]
    ax.scatter(Xtmp, y)
    ax.set_xlabel(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Prediction of a Player’s Rating

# %% [markdown]
# ## Feature selection

# %%
lm = LinearRegression()

rfe = RFE(lm, n_features_to_select = 50)
rfe_fit = rfe.fit(X, y)

for feat in df_vals.columns[rfe_fit.support_]:
    print(feat)
# Out:
# player_id
# age
# potential
# crossing
# finishing
# heading_accuracy
# short_passing
# volleys
# dribbling
# curve
# fk_accuracy
# long_passing
# ball_control
# acceleration
# sprint_speed
# agility
# reactions
# balance
# shot_power
# jumping
# stamina
# strength
# long_shots
# aggression
# interceptions
# positioning
# vision
# penalties
# composure
# marking
# standing_tackle
# sliding_tackle
# gk_diving
# gk_handling
# gk_kicking
# gk_positioning
# gk_reflexes

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# %%
# Import classifiers
# from sklearn.neural_network import MLPRegressor
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.svm import SVC
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor, ExtraTreesRegressor
# from sklearn.naive_bayes import GaussianNB
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import Ridge, LinearRegression, Lasso, LogisticRegression
# from xgboost import XGBRegressor

#Import helper functions
from sklearn.model_selection import learning_curve, StratifiedKFold, train_test_split
from sklearn.metrics import r2_score

import time

# Function to help with repeated plotting of predictions
def pred_plotter(X_test, y_test, model, model_name = ""):
    preds = model.predict(X_test)
    plt.scatter(y_test, preds)
    plt.xlabel("Predicted Ratings")
    plt.ylabel("Actual Ratings")
    plt.title(model_name)

# Names of classifiers we want to use
clf_names = [
            # "KNN", "Linear SVM",
            #  "RBF SVM",
            #  "Bagging Classifier",
             "Decision Tree", 
             "Random Forest", 
            #  "Neural Net", 
            #  "AdaBoost",
            #  "Naive Bayes", 
             "GradientBooster", 
            #  "LDA",
            #  "XGBoost", 
            #  "Linear Regression",
             "Logistic Regression",
            #  "Ridge", 
            #  "Lasso"
             ]

# Implementation of each classifier we want to use, large scope in here for parameter tuning etc.
clfs = [
        # KNeighborsRegressor(3),
        # SVC(kernel="linear", C=0.025),
        # SVC(gamma=2, C=1),
        # BaggingRegressor(KNeighborsRegressor(), max_samples=0.5, max_features=0.5),
        DecisionTreeRegressor(max_depth=20),
        RandomForestClassifier(n_estimators=250, random_state=24),
        #RandomForestRegressor(max_depth=5, n_estimators=250, max_features=4),
        # MLPRegressor(alpha=1),
        # AdaBoostRegressor(),
        # GaussianNB(),
        GradientBoostingRegressor(n_estimators = 20),
        # LinearDiscriminantAnalysis(),
        # XGBRegressor(),
        # LinearRegression(),
        LogisticRegression(), 
        # Ridge(alpha = 1.0,fit_intercept=True),
        # Lasso(alpha = 1.0, fit_intercept=True)
       ]

# Create test/train splits, and initialise plotting requirements
#  We won't apply on feature reduction here, but it can be explored. 
X = df_vals.values 
X = scale(X)
y = rating.values.ravel()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)
regressor_data = pd.DataFrame(columns = ["Name", "Score", "Training_Time"])
fig = plt.figure(figsize = (15,60))
i = 0
print('here!')
# Iterate over each regressor (no cross validation/KFolds yet)
for name, clf in zip(clf_names, clfs):
    print("#" * 80)
    print("Fitting '%s' regressor." % name)
    
    # Time required to fit the regressor
    t0 = time.time()
    clf.fit(X_train, y_train)
    t1 = time.time()
    preds = clf.predict(X_test)
    score = r2_score(y_test, preds)
    print("Name: %s Score: %.2f Time %.4f secs" % (name, score, t1-t0))
    
    # Create a plot showing predictions against actual
    ax = fig.add_subplot(6,3,i+1)
    pred_plotter(X_test, y_test, clf, name)
    
    # Store results  
    regressor_data.loc[i] = [name, score, t1-t0]
    i += 1
plt.show()
# Out:
# here!
# ################################################################################
# Fitting 'Decision Tree' regressor.
# Name: Decision Tree Score: 0.93 Time 0.3049 secs
# ################################################################################
# Fitting 'Random Forest' regressor.
# Name: Random Forest Score: 0.96 Time 14.4012 secs
# ################################################################################
# Fitting 'GradientBooster' regressor.
# Name: GradientBooster Score: 0.88 Time 1.0555 secs
# ################################################################################
# Fitting 'Logistic Regression' regressor.
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Name: Logistic Regression Score: 0.90 Time 3.0149 secs

# %%
regressor_data.sort_values(by="Score", ascending = False)
# Out:
#                   Name     Score  Training_Time
# 1        Random Forest  0.960378      14.401242
# 0        Decision Tree  0.926643       0.304855
# 3  Logistic Regression  0.903018       3.014886
# 2      GradientBooster  0.882889       1.055484

# %% [markdown]
# ## Improving results

# %%
from sklearn.ensemble import BaggingRegressor

eclf1= BaggingRegressor(RandomForestClassifier(),n_estimators = 200)

eclf1.fit(X_train, y_train)
score = r2_score(y_test, eclf1.predict(X_test))
print("Bagging RF Score: ", score)
pred_plotter(X_test, y_test, eclf1, "Bagging Regressor")
plt.show()

# %% [markdown]
# ## Plot raw data for missing values

# %%
# https://github.com/ResidentMario/missingno
# !pip install missingno

import missingno as msno
plot_count = 1
column_groups = np.array_split(data.columns, plot_count)

for columns in column_groups:
    msno.bar(data[columns])
    plt.show()

# %% [markdown]
# ## Categorical and numeric attributes in raw data

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

print("Number of numeric attributes - " + str(len(data.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns)))
print("Number of categorical attributes - " + str(len(data.select_dtypes(include=['object']).columns)))
# Out:
# Number of numeric attributes - 38
# Number of categorical attributes - 24

# %% [markdown]
# ## Correlation matrix between categorical and numeric attributes

# %%
for position_value in data['field_position'].unique():
    
    corr_matrix = data[data['field_position'] == position_value].corr()['overall'].to_frame()
    temp_df = corr_matrix['overall'].sort_values(ascending=False)
    
    print(f'********** Current Position: {position_value}: \n ')
    
    print(temp_df)
    
    print('\n')

    print(f'-------------------------------------------------------------')
    
    print('\n')
# Out:
# ********** Current Position: RF:
#
# overall             1.000000
# ball_control        0.958956
# dribbling           0.955572
# short_passing       0.940942
# long_shots          0.937930
# finishing           0.930346
# crossing            0.921477
# reactions           0.916027
# potential           0.915309
# positioning         0.910259
# composure           0.880615
# vision              0.875421
# curve               0.832030
# volleys             0.777101
# fk_accuracy         0.755356
# shot_power          0.732841
# long_passing        0.703595
# balance             0.629419
# penalties           0.607810
# acceleration        0.477449
# agility             0.470159
# age                 0.378507
# sprint_speed        0.313148
# heading_accuracy    0.218312
# gk_kicking          0.124607
# jumping             0.062398
# gk_positioning      0.025783
# stamina             0.010106
# aggression         -0.034344
# sliding_tackle     -0.037647
# standing_tackle    -0.075004
# gk_handling        -0.095968
# interceptions      -0.117836
# gk_reflexes        -0.251859
# marking            -0.320490
# strength           -0.350983
# gk_diving          -0.392356
# player_id          -0.606944
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: ST:
#
# overall             1.000000
# positioning         0.906576
# finishing           0.904036
# ball_control        0.899181
# shot_power          0.878044
# reactions           0.862176
# volleys             0.829679
# composure           0.827730
# short_passing       0.817278
# dribbling           0.798908
# long_shots          0.793109
# heading_accuracy    0.708297
# vision              0.670688
# curve               0.651628
# crossing            0.616946
# penalties           0.585256
# potential           0.583946
# long_passing        0.580891
# fk_accuracy         0.579691
# age                 0.545685
# aggression          0.529674
# strength            0.485860
# stamina             0.459536
# interceptions       0.402749
# standing_tackle     0.359591
# jumping             0.339199
# marking             0.308396
# agility             0.276327
# sliding_tackle      0.263893
# sprint_speed        0.202495
# acceleration        0.163418
# gk_handling         0.082632
# gk_reflexes         0.047881
# gk_diving           0.044033
# gk_kicking          0.039834
# gk_positioning      0.025416
# balance             0.005495
# player_id          -0.478127
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LW:
#
# overall             1.000000
# ball_control        0.920381
# dribbling           0.889860
# short_passing       0.862022
# reactions           0.850375
# positioning         0.838753
# composure           0.834363
# vision              0.797904
# long_shots          0.792678
# crossing            0.752665
# finishing           0.719685
# curve               0.709553
# long_passing        0.707798
# volleys             0.694507
# shot_power          0.686011
# potential           0.635221
# fk_accuracy         0.587520
# stamina             0.538853
# agility             0.524108
# acceleration        0.512572
# penalties           0.502245
# sprint_speed        0.455192
# aggression          0.415497
# heading_accuracy    0.368662
# age                 0.355182
# interceptions       0.303270
# balance             0.296638
# marking             0.284027
# strength            0.254269
# standing_tackle     0.222333
# jumping             0.212979
# sliding_tackle      0.136740
# gk_diving           0.105363
# gk_positioning      0.095723
# gk_reflexes         0.057681
# gk_kicking          0.055179
# gk_handling         0.022541
# player_id          -0.398720
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: GK:
#
# overall             1.000000
# gk_reflexes         0.941000
# gk_diving           0.937871
# gk_positioning      0.935355
# gk_handling         0.918714
# reactions           0.857489
# gk_kicking          0.774512
# potential           0.714011
# composure           0.547686
# age                 0.501949
# sprint_speed        0.460927
# acceleration        0.450882
# jumping             0.429746
# agility             0.417853
# vision              0.415866
# interceptions       0.391692
# strength            0.360988
# positioning         0.352472
# ball_control        0.341724
# stamina             0.339520
# volleys             0.335966
# long_shots          0.331578
# finishing           0.317965
# dribbling           0.295731
# penalties           0.281742
# aggression          0.275428
# short_passing       0.274974
# long_passing        0.273732
# marking             0.204940
# curve               0.166810
# fk_accuracy         0.155161
# balance             0.149581
# shot_power          0.131820
# crossing            0.124469
# heading_accuracy    0.106258
# standing_tackle     0.097113
# sliding_tackle      0.079525
# player_id          -0.435348
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RCM:
#
# overall             1.000000
# short_passing       0.898231
# ball_control        0.877485
# long_passing        0.847331
# reactions           0.846902
# vision              0.813156
# potential           0.773846
# dribbling           0.767245
# composure           0.739686
# positioning         0.682882
# long_shots          0.676686
# shot_power          0.670438
# crossing            0.634801
# curve               0.589794
# finishing           0.577161
# interceptions       0.568489
# volleys             0.537964
# marking             0.523809
# penalties           0.509731
# fk_accuracy         0.508488
# standing_tackle     0.472723
# sliding_tackle      0.418123
# heading_accuracy    0.385195
# aggression          0.354176
# stamina             0.314083
# age                 0.247178
# strength            0.243507
# agility             0.232998
# balance             0.139736
# acceleration        0.102060
# gk_handling         0.078841
# sprint_speed        0.054721
# gk_kicking          0.052313
# gk_diving           0.031284
# jumping             0.031284
# gk_reflexes         0.018509
# gk_positioning     -0.033283
# player_id          -0.263286
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LF:
#
# overall             1.000000
# ball_control        0.967971
# vision              0.957028
# dribbling           0.953644
# positioning         0.943071
# short_passing       0.936834
# reactions           0.907239
# potential           0.889312
# finishing           0.888630
# penalties           0.881640
# composure           0.876002
# curve               0.837906
# long_passing        0.835352
# crossing            0.831820
# fk_accuracy         0.820489
# volleys             0.811848
# long_shots          0.765878
# agility             0.753708
# shot_power          0.519850
# acceleration        0.510667
# interceptions       0.413161
# sprint_speed        0.392979
# balance             0.377712
# stamina             0.315973
# strength            0.305171
# heading_accuracy    0.295900
# aggression          0.262762
# age                 0.216354
# standing_tackle     0.103622
# marking             0.096318
# sliding_tackle      0.056723
# gk_handling        -0.265147
# gk_diving          -0.326553
# gk_positioning     -0.356406
# gk_reflexes        -0.397311
# jumping            -0.435076
# player_id          -0.490635
# gk_kicking         -0.564943
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RS:
#
# overall             1.000000
# positioning         0.905301
# finishing           0.893306
# reactions           0.887877
# ball_control        0.858014
# shot_power          0.806426
# volleys             0.798842
# potential           0.798561
# composure           0.797598
# short_passing       0.785284
# long_shots          0.745570
# dribbling           0.725995
# vision              0.649786
# curve               0.629618
# penalties           0.619033
# heading_accuracy    0.535852
# long_passing        0.477492
# fk_accuracy         0.461916
# crossing            0.413639
# marking             0.393395
# aggression          0.391128
# stamina             0.293732
# age                 0.265131
# strength            0.248079
# jumping             0.236583
# standing_tackle     0.204458
# interceptions       0.187718
# agility             0.114035
# sliding_tackle      0.083120
# gk_positioning      0.082362
# sprint_speed        0.067244
# acceleration        0.053128
# gk_kicking          0.045891
# gk_diving           0.041677
# gk_reflexes         0.019661
# balance             0.014081
# gk_handling        -0.016645
# player_id          -0.213059
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RCB:
#
# overall             1.000000
# standing_tackle     0.904318
# interceptions       0.881221
# marking             0.861917
# sliding_tackle      0.846161
# reactions           0.831455
# potential           0.791189
# heading_accuracy    0.789530
# composure           0.741869
# short_passing       0.676698
# ball_control        0.657146
# aggression          0.650250
# long_passing        0.597893
# dribbling           0.462989
# shot_power          0.406414
# vision              0.385800
# strength            0.336399
# curve               0.334034
# long_shots          0.331086
# finishing           0.312371
# penalties           0.300027
# crossing            0.277933
# fk_accuracy         0.273722
# age                 0.252584
# volleys             0.247344
# positioning         0.241882
# jumping             0.235569
# stamina             0.219554
# sprint_speed        0.155474
# agility             0.128878
# acceleration        0.100823
# gk_handling         0.059374
# gk_kicking          0.053330
# gk_positioning      0.042472
# balance             0.038181
# gk_diving           0.021012
# gk_reflexes        -0.001038
# player_id          -0.299107
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LCM:
#
# overall             1.000000
# short_passing       0.900182
# ball_control        0.892131
# reactions           0.831787
# long_passing        0.827403
# composure           0.803354
# vision              0.793151
# potential           0.787228
# dribbling           0.781752
# positioning         0.667909
# shot_power          0.666053
# long_shots          0.654430
# crossing            0.646205
# curve               0.607225
# volleys             0.577664
# finishing           0.545992
# penalties           0.511851
# fk_accuracy         0.510381
# interceptions       0.440939
# standing_tackle     0.403637
# marking             0.401448
# stamina             0.357910
# aggression          0.339519
# heading_accuracy    0.293439
# sliding_tackle      0.291209
# age                 0.237369
# agility             0.226903
# strength            0.184910
# acceleration        0.140862
# balance             0.112691
# sprint_speed        0.104328
# gk_kicking          0.086845
# gk_reflexes         0.072938
# gk_handling         0.021531
# jumping            -0.009670
# gk_positioning     -0.035563
# gk_diving          -0.043104
# player_id          -0.272896
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: CB:
#
# overall             1.000000
# interceptions       0.901896
# standing_tackle     0.901333
# sliding_tackle      0.866788
# marking             0.859210
# reactions           0.856334
# heading_accuracy    0.839069
# composure           0.805325
# short_passing       0.733018
# aggression          0.732683
# ball_control        0.705050
# long_passing        0.670559
# potential           0.596158
# strength            0.563258
# shot_power          0.528045
# dribbling           0.523675
# age                 0.494341
# vision              0.454742
# long_shots          0.452978
# crossing            0.419764
# finishing           0.399533
# curve               0.399191
# fk_accuracy         0.365769
# penalties           0.347188
# positioning         0.341137
# volleys             0.338229
# stamina             0.247060
# agility             0.165847
# jumping             0.160957
# gk_diving           0.062952
# gk_kicking          0.055291
# gk_reflexes         0.045609
# sprint_speed        0.043566
# gk_handling         0.033459
# gk_positioning      0.026304
# acceleration       -0.044436
# balance            -0.134772
# player_id          -0.445717
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LDM:
#
# overall             1.000000
# reactions           0.844883
# short_passing       0.821091
# composure           0.811587
# ball_control        0.799158
# long_passing        0.793361
# interceptions       0.728374
# potential           0.709835
# standing_tackle     0.656184
# dribbling           0.653739
# vision              0.648557
# shot_power          0.566720
# long_shots          0.558893
# crossing            0.522126
# curve               0.506958
# marking             0.501720
# sliding_tackle      0.498261
# finishing           0.482362
# positioning         0.476357
# volleys             0.470897
# aggression          0.461363
# fk_accuracy         0.448275
# stamina             0.417160
# penalties           0.397111
# heading_accuracy    0.387681
# agility             0.296748
# age                 0.278072
# strength            0.235079
# jumping             0.174786
# sprint_speed        0.168104
# acceleration        0.166153
# balance             0.152617
# gk_handling         0.097194
# gk_diving           0.059106
# gk_kicking          0.020784
# gk_reflexes        -0.073005
# gk_positioning     -0.090057
# player_id          -0.290560
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: CAM:
#
# overall             1.000000
# ball_control        0.921193
# dribbling           0.871657
# vision              0.865796
# positioning         0.860948
# short_passing       0.853990
# reactions           0.851653
# long_shots          0.828208
# finishing           0.809428
# composure           0.789916
# crossing            0.788978
# shot_power          0.758047
# volleys             0.746449
# long_passing        0.738207
# curve               0.721583
# fk_accuracy         0.684058
# penalties           0.642065
# potential           0.597991
# stamina             0.517176
# age                 0.511509
# heading_accuracy    0.409268
# agility             0.376800
# interceptions       0.363253
# aggression          0.362889
# strength            0.352396
# marking             0.250772
# standing_tackle     0.238625
# acceleration        0.219205
# jumping             0.195775
# sprint_speed        0.174830
# sliding_tackle      0.096788
# balance             0.095794
# gk_reflexes         0.056936
# gk_handling         0.048993
# gk_kicking          0.029680
# gk_positioning      0.029591
# gk_diving           0.021396
# player_id          -0.475815
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: CDM:
#
# overall             1.000000
# interceptions       0.892289
# standing_tackle     0.880390
# short_passing       0.858358
# reactions           0.852623
# ball_control        0.840663
# long_passing        0.837344
# composure           0.806460
# marking             0.800162
# sliding_tackle      0.771058
# vision              0.723160
# dribbling           0.663868
# shot_power          0.636076
# potential           0.627740
# long_shots          0.626853
# aggression          0.625165
# positioning         0.575056
# crossing            0.572427
# stamina             0.557116
# curve               0.546145
# volleys             0.520994
# finishing           0.513068
# fk_accuracy         0.501682
# heading_accuracy    0.483388
# strength            0.480728
# penalties           0.478904
# age                 0.442481
# jumping             0.248831
# agility             0.154738
# gk_positioning      0.072216
# gk_handling         0.047298
# gk_diving           0.046620
# gk_reflexes         0.040218
# gk_kicking          0.026959
# acceleration        0.004682
# balance            -0.031744
# sprint_speed       -0.043222
# player_id          -0.425717
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LS:
#
# overall             1.000000
# positioning         0.899508
# ball_control        0.896109
# finishing           0.875684
# reactions           0.868560
# composure           0.827874
# shot_power          0.822499
# dribbling           0.820096
# potential           0.813882
# volleys             0.797895
# long_shots          0.784198
# short_passing       0.771651
# vision              0.652328
# penalties           0.626110
# curve               0.584454
# crossing            0.548905
# long_passing        0.526370
# fk_accuracy         0.524028
# heading_accuracy    0.491197
# aggression          0.386651
# interceptions       0.350831
# age                 0.345452
# stamina             0.293916
# marking             0.280990
# agility             0.273079
# standing_tackle     0.257170
# strength            0.249732
# sliding_tackle      0.212200
# sprint_speed        0.150727
# jumping             0.148231
# acceleration        0.138892
# balance             0.052514
# gk_handling         0.051423
# gk_diving           0.016886
# gk_kicking          0.013385
# gk_reflexes        -0.065345
# gk_positioning     -0.092048
# player_id          -0.360974
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LCB:
#
# overall             1.000000
# standing_tackle     0.905264
# interceptions       0.882956
# sliding_tackle      0.875176
# marking             0.867497
# reactions           0.838807
# potential           0.787095
# heading_accuracy    0.770697
# composure           0.734073
# aggression          0.676255
# short_passing       0.632592
# ball_control        0.625539
# long_passing        0.584101
# dribbling           0.455117
# shot_power          0.437934
# strength            0.424121
# vision              0.388881
# finishing           0.326685
# long_shots          0.316616
# curve               0.302554
# crossing            0.280229
# penalties           0.279833
# fk_accuracy         0.273369
# volleys             0.269695
# positioning         0.238778
# stamina             0.233153
# jumping             0.225223
# age                 0.209501
# sprint_speed        0.188916
# agility             0.118291
# acceleration        0.100511
# gk_positioning      0.029522
# gk_diving          -0.005702
# balance            -0.024414
# gk_handling        -0.044992
# gk_reflexes        -0.055037
# gk_kicking         -0.056196
# player_id          -0.237695
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RM:
#
# overall             1.000000
# ball_control        0.918184
# dribbling           0.885577
# short_passing       0.863989
# reactions           0.842056
# positioning         0.834001
# composure           0.819845
# vision              0.818435
# crossing            0.802935
# long_shots          0.764396
# long_passing        0.700754
# finishing           0.700562
# curve               0.700241
# shot_power          0.692084
# potential           0.665402
# volleys             0.638684
# fk_accuracy         0.580382
# stamina             0.510127
# penalties           0.507564
# agility             0.473098
# aggression          0.416622
# acceleration        0.396647
# heading_accuracy    0.390089
# age                 0.389492
# sprint_speed        0.361365
# interceptions       0.344703
# marking             0.270537
# strength            0.257872
# jumping             0.253068
# standing_tackle     0.244556
# balance             0.204719
# sliding_tackle      0.185038
# gk_kicking          0.067489
# gk_reflexes         0.058042
# gk_diving           0.054680
# gk_positioning      0.042353
# gk_handling        -0.016814
# player_id          -0.414908
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LAM:
#
# overall             1.000000
# potential           0.915881
# ball_control        0.883119
# short_passing       0.853621
# vision              0.791599
# composure           0.784814
# reactions           0.761731
# curve               0.749213
# dribbling           0.747657
# crossing            0.718986
# fk_accuracy         0.666397
# long_passing        0.661480
# finishing           0.655556
# positioning         0.643249
# volleys             0.603709
# long_shots          0.570863
# gk_reflexes         0.444584
# gk_handling         0.434708
# gk_kicking          0.401373
# penalties           0.386567
# shot_power          0.349711
# sliding_tackle      0.345121
# marking             0.317450
# aggression          0.304719
# agility             0.288898
# heading_accuracy    0.288784
# interceptions       0.246169
# standing_tackle     0.207181
# strength            0.199771
# gk_diving           0.188442
# stamina             0.077465
# age                -0.027799
# acceleration       -0.113943
# balance            -0.128924
# jumping            -0.136459
# player_id          -0.365029
# gk_positioning     -0.466872
# sprint_speed       -0.503660
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LM:
#
# overall             1.000000
# ball_control        0.909799
# dribbling           0.881169
# short_passing       0.850891
# positioning         0.845917
# reactions           0.837168
# vision              0.827211
# composure           0.800996
# crossing            0.761228
# long_shots          0.756284
# finishing           0.720653
# shot_power          0.697319
# curve               0.682696
# long_passing        0.668358
# volleys             0.649816
# potential           0.643067
# fk_accuracy         0.554320
# stamina             0.540059
# penalties           0.502133
# agility             0.469403
# acceleration        0.444549
# sprint_speed        0.428788
# age                 0.411292
# heading_accuracy    0.403947
# aggression          0.367964
# jumping             0.282301
# interceptions       0.281810
# strength            0.269509
# marking             0.230941
# balance             0.230085
# standing_tackle     0.168171
# sliding_tackle      0.110657
# gk_kicking          0.089130
# gk_diving           0.087595
# gk_positioning      0.063672
# gk_handling         0.062273
# gk_reflexes         0.014629
# player_id          -0.430746
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LB:
#
# overall             1.000000
# reactions           0.861445
# ball_control        0.857903
# interceptions       0.842721
# standing_tackle     0.842511
# sliding_tackle      0.837760
# short_passing       0.829676
# crossing            0.822388
# composure           0.804015
# marking             0.786482
# long_passing        0.722376
# dribbling           0.699270
# potential           0.645509
# shot_power          0.637936
# vision              0.631573
# curve               0.629756
# stamina             0.608381
# long_shots          0.608170
# aggression          0.605257
# heading_accuracy    0.598695
# positioning         0.595895
# volleys             0.524052
# finishing           0.517877
# fk_accuracy         0.475969
# penalties           0.451742
# age                 0.433437
# sprint_speed        0.430421
# agility             0.393147
# strength            0.376764
# acceleration        0.374843
# jumping             0.320663
# balance             0.186247
# gk_kicking          0.077843
# gk_handling         0.056602
# gk_reflexes         0.043977
# gk_positioning      0.043707
# gk_diving           0.040716
# player_id          -0.447704
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RDM:
#
# overall             1.000000
# reactions           0.823178
# short_passing       0.822064
# long_passing        0.816295
# ball_control        0.786479
# potential           0.762853
# composure           0.758388
# interceptions       0.637359
# vision              0.614068
# standing_tackle     0.584788
# marking             0.577719
# sliding_tackle      0.573619
# long_shots          0.562878
# dribbling           0.560629
# shot_power          0.559550
# aggression          0.494692
# positioning         0.465085
# volleys             0.441666
# curve               0.436558
# crossing            0.422163
# finishing           0.408166
# penalties           0.407404
# stamina             0.403967
# heading_accuracy    0.388329
# fk_accuracy         0.375094
# strength            0.294297
# age                 0.252146
# jumping             0.203437
# balance             0.171698
# agility             0.147637
# acceleration        0.139214
# gk_diving           0.121910
# sprint_speed        0.110725
# gk_handling         0.106724
# gk_positioning      0.084729
# gk_reflexes         0.024047
# gk_kicking         -0.024981
# player_id          -0.304000
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RW:
#
# overall             1.000000
# ball_control        0.915279
# dribbling           0.912599
# short_passing       0.890972
# reactions           0.881863
# positioning         0.856158
# vision              0.843791
# composure           0.821039
# crossing            0.789479
# long_shots          0.765801
# curve               0.741943
# finishing           0.725545
# long_passing        0.719757
# volleys             0.673473
# shot_power          0.652805
# potential           0.645255
# fk_accuracy         0.634255
# stamina             0.604601
# agility             0.524625
# acceleration        0.485033
# penalties           0.442750
# age                 0.442070
# aggression          0.432686
# sprint_speed        0.422204
# interceptions       0.342185
# heading_accuracy    0.313199
# balance             0.273514
# strength            0.222972
# standing_tackle     0.213927
# marking             0.170941
# jumping             0.157332
# sliding_tackle      0.134188
# gk_positioning      0.119785
# gk_kicking          0.063256
# gk_handling         0.046535
# gk_reflexes         0.012920
# gk_diving          -0.020893
# player_id          -0.435019
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: CM:
#
# overall             1.000000
# ball_control        0.930742
# short_passing       0.902620
# long_passing        0.892948
# vision              0.892209
# reactions           0.868268
# dribbling           0.866618
# composure           0.819121
# long_shots          0.803598
# crossing            0.764891
# positioning         0.760669
# shot_power          0.744449
# interceptions       0.742932
# standing_tackle     0.717108
# finishing           0.699309
# curve               0.692050
# volleys             0.659723
# marking             0.650884
# fk_accuracy         0.635436
# potential           0.626932
# penalties           0.591555
# sliding_tackle      0.577011
# stamina             0.569682
# aggression          0.520651
# age                 0.496157
# heading_accuracy    0.468018
# strength            0.463430
# agility             0.368164
# jumping             0.246429
# acceleration        0.164660
# balance             0.125769
# sprint_speed        0.107204
# gk_positioning      0.089989
# gk_reflexes         0.063722
# gk_kicking          0.053481
# gk_handling         0.040215
# gk_diving          -0.029170
# player_id          -0.420055
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RB:
#
# overall             1.000000
# standing_tackle     0.877683
# sliding_tackle      0.868314
# reactions           0.856072
# interceptions       0.852916
# ball_control        0.849649
# short_passing       0.832245
# crossing            0.815717
# composure           0.812066
# marking             0.802688
# long_passing        0.720677
# dribbling           0.695472
# potential           0.672221
# shot_power          0.631982
# vision              0.627050
# curve               0.616712
# aggression          0.610937
# heading_accuracy    0.609143
# stamina             0.601908
# positioning         0.579371
# long_shots          0.572498
# volleys             0.481915
# finishing           0.467972
# fk_accuracy         0.448751
# age                 0.430442
# penalties           0.427606
# sprint_speed        0.408946
# agility             0.393584
# acceleration        0.350908
# strength            0.340852
# jumping             0.304385
# balance             0.158481
# gk_kicking          0.072689
# gk_diving           0.060730
# gk_reflexes         0.057470
# gk_positioning      0.035343
# gk_handling         0.010954
# player_id          -0.431863
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RAM:
#
# overall             1.000000
# potential           0.948707
# short_passing       0.829544
# dribbling           0.825416
# ball_control        0.815474
# composure           0.775053
# reactions           0.739802
# vision              0.728182
# crossing            0.683136
# positioning         0.677674
# long_passing        0.582124
# curve               0.541495
# shot_power          0.499158
# fk_accuracy         0.467091
# long_shots          0.455232
# penalties           0.442130
# volleys             0.411283
# interceptions       0.402942
# agility             0.390801
# finishing           0.379836
# marking             0.367402
# gk_kicking          0.351818
# standing_tackle     0.351479
# aggression          0.302696
# sliding_tackle      0.289505
# sprint_speed        0.280449
# stamina             0.277874
# gk_reflexes         0.233393
# strength            0.210656
# acceleration        0.208788
# heading_accuracy    0.173065
# age                 0.159785
# balance             0.063826
# gk_positioning     -0.140046
# jumping            -0.301578
# player_id          -0.320999
# gk_diving          -0.467816
# gk_handling        -0.540494
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: CF:
#
# overall             1.000000
# ball_control        0.935937
# positioning         0.929499
# finishing           0.883428
# dribbling           0.882335
# reactions           0.879504
# short_passing       0.879083
# long_shots          0.877181
# composure           0.862259
# shot_power          0.770353
# volleys             0.762515
# vision              0.760689
# curve               0.710323
# fk_accuracy         0.706908
# crossing            0.704099
# long_passing        0.689256
# stamina             0.645576
# potential           0.615188
# penalties           0.532026
# aggression          0.522107
# age                 0.521860
# standing_tackle     0.505315
# marking             0.482851
# heading_accuracy    0.463041
# sliding_tackle      0.414674
# acceleration        0.410058
# agility             0.404389
# interceptions       0.394742
# sprint_speed        0.333027
# balance             0.287613
# strength            0.255229
# gk_reflexes         0.184558
# jumping             0.140338
# gk_kicking          0.069957
# gk_handling         0.069556
# gk_positioning     -0.099566
# gk_diving          -0.135359
# player_id          -0.744659
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: RWB:
#
# overall             1.000000
# ball_control        0.900407
# crossing            0.898292
# short_passing       0.877265
# marking             0.874565
# reactions           0.871515
# composure           0.849167
# standing_tackle     0.835365
# sliding_tackle      0.820762
# interceptions       0.812616
# dribbling           0.772437
# long_passing        0.770090
# potential           0.729707
# vision              0.714107
# shot_power          0.709948
# heading_accuracy    0.701881
# stamina             0.631242
# positioning         0.626020
# curve               0.611623
# aggression          0.532368
# long_shots          0.532280
# volleys             0.529456
# penalties           0.490756
# finishing           0.465358
# strength            0.458337
# fk_accuracy         0.449007
# age                 0.436419
# sprint_speed        0.431038
# acceleration        0.330725
# agility             0.237634
# jumping             0.235642
# gk_reflexes         0.226891
# gk_diving           0.160135
# balance             0.141966
# gk_positioning      0.031814
# gk_kicking          0.022843
# gk_handling        -0.125393
# player_id          -0.383984
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------
#
#
# ********** Current Position: LWB:
#
# overall             1.000000
# short_passing       0.897081
# reactions           0.877870
# crossing            0.852503
# ball_control        0.847837
# dribbling           0.814047
# long_passing        0.792822
# marking             0.787797
# interceptions       0.772958
# sliding_tackle      0.770852
# standing_tackle     0.770691
# composure           0.766633
# vision              0.732709
# potential           0.681087
# shot_power          0.671041
# positioning         0.655743
# penalties           0.651391
# curve               0.633427
# stamina             0.600314
# heading_accuracy    0.573770
# aggression          0.555818
# fk_accuracy         0.540958
# volleys             0.530218
# finishing           0.527000
# long_shots          0.520119
# age                 0.512735
# agility             0.334716
# acceleration        0.334203
# sprint_speed        0.308115
# gk_kicking          0.298929
# strength            0.298800
# gk_reflexes         0.161140
# gk_handling         0.039583
# balance             0.036609
# jumping             0.036067
# gk_diving          -0.056097
# gk_positioning     -0.115767
# player_id          -0.518833
# Name: overall, dtype: float64
#
#
# -------------------------------------------------------------

# %%
import statsmodels.api as sm

for position in data['field_position'].unique(): 
    
    try:
    
        # Subset by position
        temp_df = data[data['field_position'] == position]

        # Find correlations
        temp_corr = data[data['field_position'] == position].corr()['overall'].to_frame()
        temp_corr = temp_corr[temp_corr['overall'] > 0.5]


        # Keep only columns with correltion above 0.5
        temp_features = list(temp_corr.T)
        temp_model_df = temp_df[temp_features]

        #print(temp_features)
        # Split data into train and test, isolate y (target/dependent variable)
        train_set, test_set = train_test_split(temp_model_df, test_size=0.2, random_state=42)
        target_train = train_set['overall']
        train_set = train_set.drop(['overall'], axis = 1) #, 'potential', 'overall'], axis = 1)
        

        # Fit model
        train_set = sm.add_constant(train_set, prepend=False)

        # Fit and summarize OLS model
        mod = sm.OLS(target_train, train_set, missing='drop')

        res = mod.fit()
        
        features = pd.DataFrame([res.pvalues, res.params]).T
        features.columns = ['P-value', 'Coefficient']
        features = features[features['P-value']<0.05]
        features = features.sort_values(by = 'Coefficient', ascending = False)
    

        print(f' ********* Current Position: {position}: \n ')
        print(f' ********* Significant features in order of impact: {features.index}: \n ')
        print(res.summary())
        print('\n')
        
    except BaseException as e: 
        print(f'WARNING: SKIPPING {position} due to {e}')
# Out:
#  ********* Current Position: RF:
#
#  ********* Significant features in order of impact: Index([], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):                nan
# Time:                        22:17:12   Log-Likelihood:                 337.64
# No. Observations:                  12   AIC:                            -651.3
# Df Residuals:                       0   BIC:                            -645.5
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.1870        inf          0        nan         nan         nan
# crossing          0.2015        inf          0        nan         nan         nan
# finishing         0.1999        inf          0        nan         nan         nan
# short_passing     0.0934        inf          0        nan         nan         nan
# volleys           0.0736        inf          0        nan         nan         nan
# dribbling         0.1835        inf          0        nan         nan         nan
# curve             0.0565        inf          0        nan         nan         nan
# fk_accuracy      -0.0127        inf         -0        nan         nan         nan
# long_passing     -0.0244        inf         -0        nan         nan         nan
# ball_control      0.1156        inf          0        nan         nan         nan
# reactions         0.0930        inf          0        nan         nan         nan
# balance           0.0283        inf          0        nan         nan         nan
# shot_power       -0.0748        inf         -0        nan         nan         nan
# long_shots        0.0112        inf          0        nan         nan         nan
# positioning       0.0001        inf          0        nan         nan         nan
# vision           -0.0465        inf         -0        nan         nan         nan
# penalties        -0.0355        inf         -0        nan         nan         nan
# composure        -0.0302        inf         -0        nan         nan         nan
# const             0.0049        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.206   Durbin-Watson:                   0.096
# Prob(Omnibus):                  0.547   Jarque-Bera (JB):                0.787
# Skew:                           0.581   Prob(JB):                        0.675
# Kurtosis:                       2.529   Cond. No.                         249.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
#
#
#  ********* Current Position: ST:
#
#  ********* Significant features in order of impact: Index(['const', 'finishing', 'positioning', 'shot_power', 'dribbling',
#        'ball_control', 'heading_accuracy', 'reactions', 'potential',
#        'short_passing', 'age', 'crossing', 'long_shots', 'aggression',
#        'composure', 'vision', 'long_passing', 'fk_accuracy', 'penalties'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     4813.
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:12   Log-Likelihood:                -2274.1
# No. Observations:                1721   AIC:                             4590.
# Df Residuals:                    1700   BIC:                             4705.
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# age                  0.0223      0.011      2.089      0.037       0.001       0.043
# potential            0.0622      0.008      7.449      0.000       0.046       0.079
# crossing             0.0216      0.003      7.288      0.000       0.016       0.027
# finishing            0.1514      0.007     21.116      0.000       0.137       0.165
# heading_accuracy     0.0811      0.004     21.762      0.000       0.074       0.088
# short_passing        0.0474      0.005      9.116      0.000       0.037       0.058
# volleys              0.0042      0.004      1.114      0.266      -0.003       0.012
# dribbling            0.1227      0.006     21.260      0.000       0.111       0.134
# curve             2.679e-05      0.003      0.009      0.993      -0.006       0.006
# fk_accuracy         -0.0095      0.003     -3.613      0.000      -0.015      -0.004
# long_passing        -0.0094      0.003     -2.807      0.005      -0.016      -0.003
# ball_control         0.0869      0.007     12.216      0.000       0.073       0.101
# reactions            0.0740      0.005     14.539      0.000       0.064       0.084
# shot_power           0.1315      0.005     26.733      0.000       0.122       0.141
# long_shots           0.0185      0.005      3.839      0.000       0.009       0.028
# aggression           0.0141      0.002      7.716      0.000       0.011       0.018
# positioning          0.1455      0.006     24.926      0.000       0.134       0.157
# vision              -0.0079      0.004     -2.019      0.044      -0.016      -0.000
# penalties           -0.0142      0.004     -4.042      0.000      -0.021      -0.007
# composure            0.0115      0.004      2.642      0.008       0.003       0.020
# const                5.1077      0.436     11.717      0.000       4.253       5.963
# ==============================================================================
# Omnibus:                       47.366   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.678
# Skew:                          -0.076   Prob(JB):                     2.52e-24
# Kurtosis:                       4.222   Cond. No.                     5.16e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LW:
#
#  ********* Significant features in order of impact: Index(['ball_control', 'dribbling', 'short_passing', 'positioning',
#        'acceleration', 'finishing', 'reactions', 'crossing', 'vision',
#        'long_shots', 'potential', 'stamina'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     722.7
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):          8.95e-230
# Time:                        22:17:12   Log-Likelihood:                -390.66
# No. Observations:                 304   AIC:                             823.3
# Df Residuals:                     283   BIC:                             901.4
# Df Model:                          20
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.0279      0.012      2.340      0.020       0.004       0.051
# crossing          0.0464      0.009      4.994      0.000       0.028       0.065
# finishing         0.0996      0.011      8.908      0.000       0.078       0.122
# short_passing     0.1139      0.017      6.836      0.000       0.081       0.147
# volleys           0.0009      0.009      0.109      0.913      -0.016       0.018
# dribbling         0.1246      0.016      7.618      0.000       0.092       0.157
# curve            -0.0063      0.009     -0.743      0.458      -0.023       0.010
# fk_accuracy      -0.0007      0.006     -0.118      0.906      -0.013       0.012
# long_passing      0.0086      0.010      0.831      0.407      -0.012       0.029
# ball_control      0.1633      0.019      8.392      0.000       0.125       0.202
# acceleration      0.1025      0.009     11.017      0.000       0.084       0.121
# agility           0.0133      0.008      1.606      0.109      -0.003       0.030
# reactions         0.0927      0.010      8.825      0.000       0.072       0.113
# shot_power        0.0099      0.010      0.945      0.346      -0.011       0.030
# stamina           0.0140      0.006      2.319      0.021       0.002       0.026
# long_shots        0.0288      0.010      2.958      0.003       0.010       0.048
# positioning       0.1133      0.013      8.802      0.000       0.088       0.139
# vision            0.0422      0.011      3.816      0.000       0.020       0.064
# penalties        -0.0041      0.007     -0.561      0.575      -0.019       0.010
# composure        -0.0020      0.011     -0.187      0.852      -0.023       0.019
# const             1.2298      0.790      1.557      0.121      -0.325       2.784
# ==============================================================================
# Omnibus:                      134.483   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              968.699
# Skew:                           1.650   Prob(JB):                    4.46e-211
# Kurtosis:                      11.098   Cond. No.                     4.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: GK:
#
#  ********* Significant features in order of impact: Index(['const', 'gk_handling', 'gk_diving', 'gk_reflexes', 'gk_positioning',
#        'reactions', 'gk_kicking', 'potential', 'composure'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.014e+05
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:13   Log-Likelihood:                -454.36
# No. Observations:                1620   AIC:                             928.7
# Df Residuals:                    1610   BIC:                             982.6
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# age                0.0049      0.003      1.648      0.100      -0.001       0.011
# potential          0.0110      0.003      3.606      0.000       0.005       0.017
# reactions          0.1082      0.001     76.885      0.000       0.105       0.111
# composure          0.0017      0.001      2.078      0.038    9.47e-05       0.003
# gk_diving          0.2118      0.003     77.771      0.000       0.206       0.217
# gk_handling        0.2145      0.002     88.604      0.000       0.210       0.219
# gk_kicking         0.0491      0.002     30.704      0.000       0.046       0.052
# gk_positioning     0.2025      0.002     86.308      0.000       0.198       0.207
# gk_reflexes        0.2074      0.003     80.483      0.000       0.202       0.212
# const              0.4458      0.128      3.483      0.001       0.195       0.697
# ==============================================================================
# Omnibus:                       22.623   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.190
# Skew:                           0.197   Prob(JB):                     7.56e-07
# Kurtosis:                       3.512   Cond. No.                     2.86e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.86e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RCM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'potential', 'reactions', 'ball_control',
#        'interceptions', 'shot_power', 'composure', 'penalties'],
#       dtype='object'):
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     200.9
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):          3.12e-155
# Time:                        22:17:13   Log-Likelihood:                -594.08
# No. Observations:                 312   AIC:                             1228.
# Df Residuals:                     292   BIC:                             1303.
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.1547      0.025      6.133      0.000       0.105       0.204
# crossing          0.0112      0.017      0.648      0.518      -0.023       0.045
# finishing         0.0111      0.016      0.681      0.497      -0.021       0.043
# short_passing     0.1982      0.042      4.720      0.000       0.116       0.281
# volleys           0.0023      0.012      0.184      0.854      -0.022       0.027
# dribbling         0.0352      0.030      1.184      0.237      -0.023       0.094
# curve            -0.0107      0.015     -0.703      0.483      -0.041       0.019
# fk_accuracy      -0.0067      0.013     -0.493      0.622      -0.033       0.020
# long_passing      0.0518      0.033      1.568      0.118      -0.013       0.117
# ball_control      0.0984      0.040      2.487      0.013       0.021       0.176
# reactions         0.1489      0.025      6.009      0.000       0.100       0.198
# shot_power        0.0585      0.019      3.039      0.003       0.021       0.096
# long_shots       -0.0034      0.018     -0.187      0.851      -0.040       0.033
# interceptions     0.0670      0.014      4.654      0.000       0.039       0.095
# positioning       0.0112      0.018      0.613      0.540      -0.025       0.047
# vision            0.0466      0.026      1.784      0.075      -0.005       0.098
# penalties         0.0340      0.013      2.645      0.009       0.009       0.059
# composure         0.0511      0.018      2.914      0.004       0.017       0.086
# marking           0.0111      0.014      0.791      0.430      -0.017       0.039
# const             3.3504      1.233      2.718      0.007       0.925       5.776
# ==============================================================================
# Omnibus:                       51.391   Durbin-Watson:                   2.118
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.309
# Skew:                           0.902   Prob(JB):                     3.32e-21
# Kurtosis:                       5.000   Cond. No.                     3.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LF:
#
#  ********* Significant features in order of impact: Index([], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):                nan
# Time:                        22:17:13   Log-Likelihood:                 338.84
# No. Observations:                  12   AIC:                            -653.7
# Df Residuals:                       0   BIC:                            -647.9
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.1009        inf          0        nan         nan         nan
# crossing         -0.0225        inf         -0        nan         nan         nan
# finishing         0.0668        inf          0        nan         nan         nan
# short_passing     0.1648        inf          0        nan         nan         nan
# volleys           0.0299        inf          0        nan         nan         nan
# dribbling         0.0891        inf          0        nan         nan         nan
# curve             0.0267        inf          0        nan         nan         nan
# fk_accuracy      -0.0254        inf         -0        nan         nan         nan
# long_passing      0.0410        inf          0        nan         nan         nan
# ball_control      0.0895        inf          0        nan         nan         nan
# acceleration      0.0457        inf          0        nan         nan         nan
# agility          -0.0003        inf         -0        nan         nan         nan
# reactions         0.0541        inf          0        nan         nan         nan
# shot_power        0.0608        inf          0        nan         nan         nan
# long_shots        0.0512        inf          0        nan         nan         nan
# positioning       0.0726        inf          0        nan         nan         nan
# vision            0.1057        inf          0        nan         nan         nan
# penalties         0.0001        inf          0        nan         nan         nan
# composure         0.0686        inf          0        nan         nan         nan
# const             0.0011        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        2.094   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.351   Jarque-Bera (JB):                1.226
# Skew:                           0.504   Prob(JB):                        0.542
# Kurtosis:                       1.802   Cond. No.                         186.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
#
#
#  ********* Current Position: RS:
#
#  ********* Significant features in order of impact: Index(['const', 'positioning', 'shot_power', 'dribbling', 'finishing',
#        'reactions', 'potential', 'short_passing', 'composure',
#        'heading_accuracy'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     374.3
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):          2.46e-108
# Time:                        22:17:13   Log-Likelihood:                -228.07
# No. Observations:                 162   AIC:                             488.1
# Df Residuals:                     146   BIC:                             537.5
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# potential            0.0808      0.025      3.180      0.002       0.031       0.131
# finishing            0.1160      0.027      4.278      0.000       0.062       0.170
# heading_accuracy     0.0300      0.012      2.427      0.016       0.006       0.054
# short_passing        0.0437      0.021      2.125      0.035       0.003       0.084
# volleys              0.0004      0.016      0.029      0.977      -0.030       0.031
# dribbling            0.1364      0.022      6.215      0.000       0.093       0.180
# curve                0.0089      0.011      0.815      0.417      -0.013       0.030
# ball_control         0.0483      0.026      1.840      0.068      -0.004       0.100
# reactions            0.0990      0.025      3.893      0.000       0.049       0.149
# shot_power           0.1512      0.019      8.114      0.000       0.114       0.188
# long_shots           0.0082      0.018      0.450      0.654      -0.028       0.044
# positioning          0.1880      0.028      6.666      0.000       0.132       0.244
# vision              -0.0286      0.016     -1.806      0.073      -0.060       0.003
# penalties           -0.0109      0.013     -0.836      0.404      -0.037       0.015
# composure            0.0367      0.015      2.416      0.017       0.007       0.067
# const                7.3031      1.065      6.859      0.000       5.199       9.407
# ==============================================================================
# Omnibus:                       19.051   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.452
# Skew:                           0.557   Prob(JB):                     2.00e-08
# Kurtosis:                       5.002   Cond. No.                     3.32e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RCB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'marking', 'heading_accuracy',
#        'interceptions', 'aggression', 'sliding_tackle', 'potential',
#        'reactions', 'ball_control', 'short_passing'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     1854.
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:13   Log-Likelihood:                -662.00
# No. Observations:                 529   AIC:                             1350.
# Df Residuals:                     516   BIC:                             1406.
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# potential            0.0621      0.011      5.677      0.000       0.041       0.084
# heading_accuracy     0.1077      0.007     14.483      0.000       0.093       0.122
# short_passing        0.0264      0.008      3.489      0.001       0.012       0.041
# long_passing         0.0098      0.006      1.759      0.079      -0.001       0.021
# ball_control         0.0416      0.007      6.227      0.000       0.028       0.055
# reactions            0.0507      0.009      5.633      0.000       0.033       0.068
# aggression           0.0917      0.005     18.447      0.000       0.082       0.101
# interceptions        0.0968      0.010      9.376      0.000       0.077       0.117
# composure            0.0096      0.007      1.355      0.176      -0.004       0.024
# marking              0.1368      0.009     14.606      0.000       0.118       0.155
# standing_tackle      0.1983      0.016     12.772      0.000       0.168       0.229
# sliding_tackle       0.0911      0.012      7.449      0.000       0.067       0.115
# const                6.8862      0.498     13.827      0.000       5.908       7.865
# ==============================================================================
# Omnibus:                       31.415   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              103.647
# Skew:                           0.108   Prob(JB):                     3.11e-23
# Kurtosis:                       5.158   Cond. No.                     3.03e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LCM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'reactions', 'potential', 'ball_control',
#        'composure', 'shot_power'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     177.5
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):          1.11e-144
# Time:                        22:17:13   Log-Likelihood:                -631.06
# No. Observations:                 316   AIC:                             1298.
# Df Residuals:                     298   BIC:                             1366.
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.1393      0.029      4.884      0.000       0.083       0.195
# crossing          0.0037      0.017      0.221      0.825      -0.029       0.037
# finishing         0.0215      0.017      1.292      0.198      -0.011       0.054
# short_passing     0.2565      0.045      5.651      0.000       0.167       0.346
# volleys          -0.0213      0.014     -1.515      0.131      -0.049       0.006
# dribbling         0.0135      0.032      0.419      0.675      -0.050       0.077
# curve             0.0165      0.016      1.020      0.308      -0.015       0.048
# fk_accuracy      -0.0191      0.015     -1.289      0.198      -0.048       0.010
# long_passing      0.0487      0.034      1.443      0.150      -0.018       0.115
# ball_control      0.1195      0.042      2.818      0.005       0.036       0.203
# reactions         0.2085      0.022      9.492      0.000       0.165       0.252
# shot_power        0.0665      0.020      3.370      0.001       0.028       0.105
# long_shots        0.0082      0.019      0.433      0.665      -0.029       0.045
# positioning      -0.0028      0.021     -0.133      0.894      -0.044       0.038
# vision            0.0190      0.026      0.729      0.467      -0.032       0.070
# penalties        -0.0019      0.014     -0.137      0.891      -0.029       0.025
# composure         0.0667      0.020      3.401      0.001       0.028       0.105
# const             4.1145      1.362      3.020      0.003       1.434       6.795
# ==============================================================================
# Omnibus:                        7.634   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                7.790
# Skew:                           0.308   Prob(JB):                       0.0203
# Kurtosis:                       3.461   Cond. No.                     3.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CB:
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'marking', 'interceptions',
#        'sliding_tackle', 'strength', 'heading_accuracy', 'aggression',
#        'reactions', 'short_passing', 'ball_control', 'potential', 'composure',
#        'dribbling'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.012e+04
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:13   Log-Likelihood:                -1368.8
# No. Observations:                1422   AIC:                             2770.
# Df Residuals:                    1406   BIC:                             2854.
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# potential            0.0328      0.004      8.451      0.000       0.025       0.040
# heading_accuracy     0.0846      0.003     24.352      0.000       0.078       0.091
# short_passing        0.0511      0.003     14.669      0.000       0.044       0.058
# dribbling            0.0050      0.002      2.193      0.028       0.001       0.009
# long_passing        -0.0020      0.003     -0.770      0.442      -0.007       0.003
# ball_control         0.0413      0.003     12.792      0.000       0.035       0.048
# reactions            0.0584      0.004     15.042      0.000       0.051       0.066
# shot_power          -0.0019      0.002     -1.090      0.276      -0.005       0.001
# strength             0.0914      0.002     37.141      0.000       0.087       0.096
# aggression           0.0696      0.002     30.016      0.000       0.065       0.074
# interceptions        0.1235      0.005     27.372      0.000       0.115       0.132
# composure            0.0122      0.003      4.075      0.000       0.006       0.018
# marking              0.1346      0.004     36.621      0.000       0.127       0.142
# standing_tackle      0.1572      0.007     23.676      0.000       0.144       0.170
# sliding_tackle       0.1091      0.006     19.298      0.000       0.098       0.120
# const                3.2479      0.241     13.483      0.000       2.775       3.720
# ==============================================================================
# Omnibus:                     1605.579   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           713990.339
# Skew:                           4.966   Prob(JB):                         0.00
# Kurtosis:                     112.324   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LDM:
#
#  ********* Significant features in order of impact: Index(['const', 'reactions', 'short_passing', 'long_passing', 'potential',
#        'interceptions', 'composure', 'standing_tackle', 'ball_control',
#        'shot_power', 'vision'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     180.0
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):           5.85e-99
# Time:                        22:17:13   Log-Likelihood:                -343.96
# No. Observations:                 194   AIC:                             719.9
# Df Residuals:                     178   BIC:                             772.2
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# potential           0.1170      0.029      4.100      0.000       0.061       0.173
# crossing            0.0287      0.015      1.903      0.059      -0.001       0.059
# short_passing       0.1356      0.043      3.175      0.002       0.051       0.220
# dribbling           0.0228      0.024      0.963      0.337      -0.024       0.069
# curve              -0.0059      0.013     -0.466      0.641      -0.031       0.019
# long_passing        0.1345      0.033      4.070      0.000       0.069       0.200
# ball_control        0.0664      0.033      2.009      0.046       0.001       0.132
# reactions           0.1699      0.027      6.268      0.000       0.116       0.223
# shot_power          0.0547      0.018      3.024      0.003       0.019       0.090
# long_shots         -0.0002      0.015     -0.011      0.991      -0.030       0.030
# interceptions       0.1027      0.024      4.333      0.000       0.056       0.150
# vision             -0.0535      0.021     -2.529      0.012      -0.095      -0.012
# composure           0.1002      0.021      4.774      0.000       0.059       0.142
# marking            -0.0058      0.017     -0.348      0.729      -0.039       0.027
# standing_tackle     0.0951      0.025      3.880      0.000       0.047       0.143
# const               4.2473      1.514      2.805      0.006       1.259       7.235
# ==============================================================================
# Omnibus:                        1.171   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.557   Jarque-Bera (JB):                0.822
# Skew:                           0.071   Prob(JB):                        0.663
# Kurtosis:                       3.285   Cond. No.                     3.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CAM:
#
#  ********* Significant features in order of impact: Index(['potential', 'age', 'dribbling', 'reactions', 'short_passing', 'vision',
#        'positioning', 'ball_control', 'finishing', 'long_shots', 'stamina',
#        'crossing'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     1383.
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:13   Log-Likelihood:                -1209.1
# No. Observations:                 766   AIC:                             2458.
# Df Residuals:                     746   BIC:                             2551.
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# age               0.1541      0.020      7.708      0.000       0.115       0.193
# potential         0.1907      0.015     12.488      0.000       0.161       0.221
# crossing          0.0172      0.008      2.236      0.026       0.002       0.032
# finishing         0.0486      0.008      5.754      0.000       0.032       0.065
# short_passing     0.1086      0.014      7.644      0.000       0.081       0.136
# volleys           0.0050      0.007      0.735      0.462      -0.008       0.018
# dribbling         0.1367      0.013     10.877      0.000       0.112       0.161
# curve             0.0075      0.007      1.049      0.294      -0.007       0.021
# fk_accuracy      -0.0070      0.006     -1.131      0.258      -0.019       0.005
# long_passing      0.0128      0.011      1.212      0.226      -0.008       0.034
# ball_control      0.0764      0.017      4.460      0.000       0.043       0.110
# reactions         0.1098      0.009     12.283      0.000       0.092       0.127
# shot_power        0.0064      0.008      0.773      0.440      -0.010       0.023
# stamina           0.0319      0.004      7.447      0.000       0.023       0.040
# long_shots        0.0449      0.008      5.650      0.000       0.029       0.061
# positioning       0.0788      0.009      8.728      0.000       0.061       0.097
# vision            0.0870      0.011      8.248      0.000       0.066       0.108
# penalties        -0.0096      0.006     -1.506      0.132      -0.022       0.003
# composure         0.0020      0.008      0.237      0.813      -0.014       0.018
# const             0.1922      0.847      0.227      0.821      -1.471       1.855
# ==============================================================================
# Omnibus:                     1142.849   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           692401.689
# Skew:                           8.088   Prob(JB):                         0.00
# Kurtosis:                     149.398   Cond. No.                     5.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CDM:
#
#  ********* Significant features in order of impact: Index(['const', 'short_passing', 'interceptions', 'standing_tackle',
#        'ball_control', 'long_passing', 'marking', 'reactions', 'stamina',
#        'aggression', 'vision', 'sliding_tackle', 'potential', 'composure'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     2677.
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):               0.00
# Time:                        22:17:13   Log-Likelihood:                -843.72
# No. Observations:                 758   AIC:                             1733.
# Df Residuals:                     735   BIC:                             1840.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# potential           0.0152      0.006      2.377      0.018       0.003       0.028
# crossing           -0.0039      0.004     -0.947      0.344      -0.012       0.004
# finishing           0.0002      0.004      0.063      0.950      -0.008       0.008
# short_passing       0.1444      0.009     15.890      0.000       0.127       0.162
# volleys             0.0012      0.004      0.311      0.756      -0.006       0.009
# dribbling          -0.0003      0.006     -0.054      0.957      -0.012       0.011
# curve              -0.0010      0.004     -0.260      0.795      -0.009       0.007
# fk_accuracy         0.0057      0.004      1.594      0.111      -0.001       0.013
# long_passing        0.0995      0.008     12.860      0.000       0.084       0.115
# ball_control        0.1031      0.009     12.117      0.000       0.086       0.120
# reactions           0.0728      0.007     10.819      0.000       0.060       0.086
# shot_power          0.0002      0.004      0.043      0.965      -0.008       0.009
# stamina             0.0659      0.003     22.252      0.000       0.060       0.072
# long_shots          0.0012      0.004      0.303      0.762      -0.006       0.009
# aggression          0.0497      0.004     13.384      0.000       0.042       0.057
# interceptions       0.1396      0.007     21.126      0.000       0.127       0.153
# positioning         0.0007      0.004      0.182      0.856      -0.007       0.008
# vision              0.0385      0.005      7.573      0.000       0.029       0.048
# composure           0.0109      0.005      2.333      0.020       0.002       0.020
# marking             0.0904      0.005     16.876      0.000       0.080       0.101
# standing_tackle     0.1272      0.010     13.314      0.000       0.108       0.146
# sliding_tackle      0.0267      0.007      3.557      0.000       0.012       0.041
# const               1.9185      0.363      5.278      0.000       1.205       2.632
# ==============================================================================
# Omnibus:                      350.802   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6869.298
# Skew:                           1.599   Prob(JB):                         0.00
# Kurtosis:                      17.397   Cond. No.                     3.79e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LS:
#
# ...
# const                3.5102      0.415      8.457      0.000       2.696       4.325
# ==============================================================================
# Omnibus:                      323.488   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2528.222
# Skew:                           1.216   Prob(JB):                         0.00
# Kurtosis:                      10.272   Cond. No.                     3.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RAM:
#
#  ********* Significant features in order of impact: Index([], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     28.14
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):            0.00280
# Time:                        22:17:13   Log-Likelihood:                -4.4735
# No. Observations:                  16   AIC:                             32.95
# Df Residuals:                       4   BIC:                             42.22
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# potential         0.1064      0.194      0.549      0.612      -0.432       0.644
# crossing         -0.0222      0.090     -0.246      0.818      -0.273       0.228
# short_passing     0.2392      0.106      2.259      0.087      -0.055       0.533
# dribbling         0.2102      0.102      2.056      0.109      -0.074       0.494
# curve             0.0041      0.033      0.124      0.908      -0.087       0.095
# long_passing      0.0759      0.031      2.427      0.072      -0.011       0.163
# ball_control      0.2916      0.174      1.676      0.169      -0.191       0.775
# reactions         0.2269      0.092      2.465      0.069      -0.029       0.483
# positioning       0.0683      0.137      0.499      0.644      -0.311       0.448
# vision           -0.0373      0.068     -0.544      0.615      -0.227       0.153
# composure        -0.0345      0.064     -0.539      0.618      -0.212       0.143
# const            -8.8006      7.516     -1.171      0.307     -29.667      12.066
# ==============================================================================
# Omnibus:                        1.621   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.445   Jarque-Bera (JB):                1.230
# Skew:                          -0.632   Prob(JB):                        0.541
# Kurtosis:                       2.501   Cond. No.                     1.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: CF:
#
#  ********* Significant features in order of impact: Index(['ball_control', 'positioning', 'dribbling', 'reactions', 'shot_power'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     135.3
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):           8.94e-29
# Time:                        22:17:13   Log-Likelihood:                -72.083
# No. Observations:                  59   AIC:                             188.2
# Df Residuals:                      37   BIC:                             233.9
# Df Model:                          21
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# age                 0.0769      0.102      0.757      0.454      -0.129       0.283
# potential           0.1248      0.063      1.996      0.053      -0.002       0.252
# crossing            0.0133      0.025      0.524      0.604      -0.038       0.065
# finishing           0.0937      0.046      2.022      0.050      -0.000       0.187
# short_passing     8.56e-05      0.044      0.002      0.998      -0.089       0.089
# volleys            -0.0009      0.025     -0.037      0.971      -0.052       0.051
# dribbling           0.1645      0.043      3.784      0.001       0.076       0.253
# curve              -0.0191      0.031     -0.609      0.546      -0.083       0.044
# fk_accuracy         0.0053      0.025      0.208      0.836      -0.046       0.057
# long_passing       -0.0090      0.026     -0.352      0.727      -0.061       0.043
# ball_control        0.1849      0.061      3.031      0.004       0.061       0.309
# reactions           0.0874      0.039      2.216      0.033       0.008       0.167
# shot_power          0.0711      0.031      2.264      0.030       0.007       0.135
# stamina             0.0224      0.029      0.773      0.444      -0.036       0.081
# long_shots          0.0296      0.042      0.706      0.485      -0.055       0.114
# aggression          0.0042      0.018      0.237      0.814      -0.032       0.040
# positioning         0.1684      0.041      4.134      0.000       0.086       0.251
# vision              0.0355      0.035      1.011      0.319      -0.036       0.107
# penalties           0.0067      0.025      0.263      0.794      -0.045       0.058
# composure           0.0184      0.031      0.591      0.558      -0.045       0.081
# standing_tackle     0.0026      0.018      0.150      0.881      -0.033       0.038
# const              -2.3654      3.682     -0.642      0.525      -9.826       5.096
# ==============================================================================
# Omnibus:                        3.127   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.209   Jarque-Bera (JB):                2.410
# Skew:                           0.484   Prob(JB):                        0.300
# Kurtosis:                       3.209   Cond. No.                     7.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: RWB:
#
#  ********* Significant features in order of impact: Index(['const', 'standing_tackle', 'crossing', 'stamina', 'interceptions',
#        'ball_control', 'dribbling', 'composure'],
#       dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                     215.1
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):           1.10e-39
# Time:                        22:17:13   Log-Likelihood:                -75.347
# No. Observations:                  69   AIC:                             194.7
# Df Residuals:                      47   BIC:                             243.8
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# potential            0.0291      0.031      0.930      0.357      -0.034       0.092
# crossing             0.1400      0.025      5.580      0.000       0.089       0.190
# heading_accuracy     0.0128      0.018      0.696      0.490      -0.024       0.050
# short_passing        0.0724      0.039      1.860      0.069      -0.006       0.151
# volleys             -0.0177      0.017     -1.066      0.292      -0.051       0.016
# dribbling            0.0786      0.028      2.824      0.007       0.023       0.135
# curve                0.0246      0.013      1.916      0.062      -0.001       0.051
# long_passing        -0.0004      0.028     -0.013      0.989      -0.056       0.055
# ball_control         0.0886      0.035      2.513      0.015       0.018       0.160
# reactions            0.0588      0.039      1.497      0.141      -0.020       0.138
# shot_power           0.0100      0.018      0.565      0.575      -0.026       0.046
# stamina              0.1380      0.018      7.663      0.000       0.102       0.174
# long_shots          -0.0225      0.017     -1.334      0.188      -0.056       0.011
# aggression          -0.0225      0.015     -1.524      0.134      -0.052       0.007
# interceptions        0.1326      0.032      4.151      0.000       0.068       0.197
# positioning          0.0141      0.018      0.805      0.425      -0.021       0.049
# vision              -0.0104      0.022     -0.474      0.638      -0.055       0.034
# composure            0.0578      0.024      2.410      0.020       0.010       0.106
# marking             -0.0232      0.037     -0.622      0.537      -0.098       0.052
# standing_tackle      0.1804      0.046      3.944      0.000       0.088       0.272
# sliding_tackle       0.0156      0.043      0.358      0.722      -0.072       0.103
# const                4.0645      1.785      2.278      0.027       0.474       7.655
# ==============================================================================
# Omnibus:                        0.046   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.977   Jarque-Bera (JB):                0.020
# Skew:                           0.008   Prob(JB):                        0.990
# Kurtosis:                       2.918   Cond. No.                     4.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#  ********* Current Position: LWB:
#
#  ********* Significant features in order of impact: Index(['age', 'potential', 'marking', 'interceptions', 'const'], dtype='object'):
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     53.47
# Date:                Mon, 19 Jul 2021   Prob (F-statistic):           1.42e-21
# Time:                        22:17:13   Log-Likelihood:                -92.922
# No. Observations:                  62   AIC:                             237.8
# Df Residuals:                      36   BIC:                             293.1
# Df Model:                          25
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# age                  0.5211      0.116      4.486      0.000       0.286       0.757
# potential            0.4421      0.083      5.322      0.000       0.274       0.611
# crossing             0.0800      0.048      1.667      0.104      -0.017       0.177
# finishing            0.0594      0.035      1.692      0.099      -0.012       0.131
# heading_accuracy     0.0169      0.035      0.478      0.635      -0.055       0.089
# short_passing        0.1377      0.072      1.921      0.063      -0.008       0.283
# volleys             -0.0078      0.030     -0.258      0.798      -0.069       0.054
# dribbling           -0.0168      0.057     -0.297      0.768      -0.132       0.098
# curve                0.0024      0.031      0.078      0.938      -0.061       0.065
# fk_accuracy         -0.0457      0.030     -1.525      0.136      -0.107       0.015
# long_passing        -0.0410      0.056     -0.730      0.470      -0.155       0.073
# ball_control         0.0002      0.052      0.004      0.996      -0.105       0.106
# reactions            0.0677      0.051      1.337      0.190      -0.035       0.170
# shot_power           0.0244      0.037      0.664      0.511      -0.050       0.099
# stamina              0.0626      0.039      1.594      0.120      -0.017       0.142
# long_shots          -0.0162      0.043     -0.376      0.709      -0.104       0.071
# aggression          -0.0093      0.026     -0.362      0.719      -0.061       0.043
# interceptions        0.1023      0.046      2.208      0.034       0.008       0.196
# positioning         -0.0060      0.028     -0.211      0.834      -0.064       0.052
# vision               0.0462      0.040      1.165      0.252      -0.034       0.127
# penalties            0.0280      0.030      0.932      0.357      -0.033       0.089
# composure           -0.0107      0.038     -0.283      0.779      -0.087       0.066
# marking              0.1219      0.057      2.123      0.041       0.005       0.238
# standing_tackle     -0.0934      0.083     -1.131      0.266      -0.261       0.074
# sliding_tackle       0.0588      0.091      0.642      0.525      -0.127       0.244
# const              -12.4920      5.017     -2.490      0.018     -22.666      -2.318
# ==============================================================================
# Omnibus:                        0.467   Durbin-Watson:                   1.684
# Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.601
# Skew:                          -0.017   Prob(JB):                        0.740
# Kurtosis:                       2.519   Cond. No.                     8.03e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.03e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\alexv\anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
print(f'in the dataset there are {len(data.columns)} columns and {len(data)} rows')
# Out:
# in the dataset there are 62 columns and 18147 rows
